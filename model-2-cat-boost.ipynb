# %% [markdown]
# ## CAT BOOST REGRESSOR

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
color = sns.color_palette()
import zipfile
import re
from scipy import stats
from catboost import CatBoostRegressor
from tqdm import tqdm
import gc
import datetime as dt

# %% [markdown]
# <font color = blue> Once we have imported the necessary libraries, we are going to define our data path and then, load the data: </font>

# %%
data_path = './data/'

# %%
print('Loading Properties ...')
properties2016 = pd.read_csv(data_path + 'properties_2016.csv', low_memory = False)
properties2017 = pd.read_csv(data_path + 'properties_2017.csv', low_memory = False)
# Out:
# Loading Properties ...

# %%
properties2016.head()
# Out:
#    parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0  10754147                    NaN                       NaN           NaN
# 1  10759547                    NaN                       NaN           NaN
# 2  10843547                    NaN                       NaN           NaN
# 3  10859147                    NaN                       NaN           NaN
# 4  10879947                    NaN                       NaN           NaN
#
#    bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  \
# 0          0.0         0.0                  NaN                    NaN
# 1          0.0         0.0                  NaN                    NaN
# 2          0.0         0.0                  NaN                    NaN
# 3          0.0         0.0                  3.0                    7.0
# 4          0.0         0.0                  4.0                    NaN
#
#    calculatedbathnbr  decktypeid  ...  numberofstories  fireplaceflag  \
# 0                NaN         NaN  ...              NaN            NaN
# 1                NaN         NaN  ...              NaN            NaN
# 2                NaN         NaN  ...              NaN            NaN
# 3                NaN         NaN  ...              1.0            NaN
# 4                NaN         NaN  ...              NaN            NaN
#
#    structuretaxvaluedollarcnt  taxvaluedollarcnt  assessmentyear  \
# 0                         NaN                9.0          2015.0
# 1                         NaN            27516.0          2015.0
# 2                    650756.0          1413387.0          2015.0
# 3                    571346.0          1156834.0          2015.0
# 4                    193796.0           433491.0          2015.0
#
#    landtaxvaluedollarcnt  taxamount  taxdelinquencyflag  taxdelinquencyyear  \
# 0                    9.0        NaN                 NaN                 NaN
# 1                27516.0        NaN                 NaN                 NaN
# 2               762631.0   20800.37                 NaN                 NaN
# 3               585488.0   14557.57                 NaN                 NaN
# 4               239695.0    5725.17                 NaN                 NaN
#
#    censustractandblock
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
# [5 rows x 58 columns]

# %%
properties2016.shape
# Out:
# (2985217, 58)

# %%
properties2017.head()
# Out:
#    parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0  10754147                    NaN                       NaN           NaN
# 1  10759547                    NaN                       NaN           NaN
# 2  10843547                    NaN                       NaN           NaN
# 3  10859147                    NaN                       NaN           NaN
# 4  10879947                    NaN                       NaN           NaN
#
#    bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  \
# 0          0.0         0.0                  NaN                    NaN
# 1          0.0         0.0                  NaN                    NaN
# 2          0.0         0.0                  5.0                    NaN
# 3          0.0         0.0                  3.0                    6.0
# 4          0.0         0.0                  4.0                    NaN
#
#    calculatedbathnbr  decktypeid  ...  numberofstories  fireplaceflag  \
# 0                NaN         NaN  ...              NaN            NaN
# 1                NaN         NaN  ...              NaN            NaN
# 2                NaN         NaN  ...              1.0            NaN
# 3                NaN         NaN  ...              1.0            NaN
# 4                NaN         NaN  ...              1.0            NaN
#
#    structuretaxvaluedollarcnt  taxvaluedollarcnt  assessmentyear  \
# 0                         NaN                9.0          2016.0
# 1                         NaN            27516.0          2015.0
# 2                    660680.0          1434941.0          2016.0
# 3                    580059.0          1174475.0          2016.0
# 4                    196751.0           440101.0          2016.0
#
#    landtaxvaluedollarcnt  taxamount  taxdelinquencyflag  taxdelinquencyyear  \
# 0                    9.0        NaN                 NaN                 NaN
# 1                27516.0        NaN                 NaN                 NaN
# 2               774261.0   20800.37                 NaN                 NaN
# 3               594416.0   14557.57                 NaN                 NaN
# 4               243350.0    5725.17                 NaN                 NaN
#
#    censustractandblock
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
# [5 rows x 58 columns]

# %%
properties2017.shape
# Out:
# (2985217, 58)

# %% [markdown]
# <font color = blue> We are going to specify the parameter 'parse_dates' to make the column 'transactiondate' in train files date formatted: </font>

# %%
print('Loading Train ...')
train2016 = pd.read_csv(data_path + 'train_2016_v2.csv', parse_dates=['transactiondate'], low_memory=False)
train2017 = pd.read_csv(data_path + 'train_2017.csv', parse_dates=['transactiondate'], low_memory=False)
# Out:
# Loading Train ...

# %%
train2016.shape
# Out:
# (90275, 3)

# %%
train2017.shape
# Out:
# (77613, 3)

# %%
train2016.head()
# Out:
#    parcelid  logerror transactiondate
# 0  11016594    0.0276      2016-01-01
# 1  14366692   -0.1684      2016-01-01
# 2  12098116   -0.0040      2016-01-01
# 3  12643413    0.0218      2016-01-02
# 4  14432541   -0.0050      2016-01-02

# %% [markdown]
# <font color = blue> Now we are going to parse dates to get one column for year, one for month, one for day and one for quarter: </font>

# %%
def add_date_features(df):
    df["transaction_year"] = df["transactiondate"].dt.year
    df["transaction_month"] = (df["transactiondate"].dt.year - 2016)*12 + df["transactiondate"].dt.month
    df["transaction_day"] = df["transactiondate"].dt.day
    df["transaction_quarter"] = (df["transactiondate"].dt.year - 2016)*4 + df["transactiondate"].dt.quarter
    df.drop(["transactiondate"], inplace=True, axis=1)
    return df

# %%
train2016 = add_date_features(train2016)
train2017 = add_date_features(train2017)

# %%
train2016.head()
# Out:
#    parcelid  logerror  transaction_year  transaction_month  transaction_day  \
# 0  11016594    0.0276              2016                  1                1
# 1  14366692   -0.1684              2016                  1                1
# 2  12098116   -0.0040              2016                  1                1
# 3  12643413    0.0218              2016                  1                2
# 4  14432541   -0.0050              2016                  1                2
#
#    transaction_quarter
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    1

# %%
print('Loading Sample ...')
sample_submission = pd.read_csv(data_path + 'sample_submission.csv', low_memory = False)
# Out:
# Loading Sample ...

# %% [markdown]
# <font color = blue> Our sample submission will be a file with the parcel id for each property and six prediction columns for different dates (last 2016 quarter and last 2017 quarter): </font>

# %%
sample_submission.head()
# Out:
#    ParcelId  201610  201611  201612  201710  201711  201712
# 0  10754147       0       0       0       0       0       0
# 1  10759547       0       0       0       0       0       0
# 2  10843547       0       0       0       0       0       0
# 3  10859147       0       0       0       0       0       0
# 4  10879947       0       0       0       0       0       0

# %% [markdown]
# <font color = blue> As we are going to apply the first model, cat boost, to the column for 201710 predictions, we remove the other columns: </font>

# %%
sample_submission_model_1 = sample_submission.drop(columns = ['201610', '201611', '201612', '201711', '201712'])
sample_submission_model_1.head()
# Out:
#    ParcelId  201710
# 0  10754147       0
# 1  10759547       0
# 2  10843547       0
# 3  10859147       0
# 4  10879947       0

# %% [markdown]
# <font color = blue> We will merge properties and train files to get all data grouped: </font>

# %%
print('Merging Train with Properties ...')
train2016 = pd.merge(train2016, properties2016, how = 'left', on = 'parcelid')
train2017 = pd.merge(train2017, properties2017, how = 'left', on = 'parcelid')
# Out:
# Merging Train with Properties ...

# %%
train2016.head()
# Out:
#    parcelid  logerror  transaction_year  transaction_month  transaction_day  \
# 0  11016594    0.0276              2016                  1                1
# 1  14366692   -0.1684              2016                  1                1
# 2  12098116   -0.0040              2016                  1                1
# 3  12643413    0.0218              2016                  1                2
# 4  14432541   -0.0050              2016                  1                2
#
#    transaction_quarter  airconditioningtypeid  architecturalstyletypeid  \
# 0                    1                    1.0                       NaN
# 1                    1                    NaN                       NaN
# 2                    1                    1.0                       NaN
# 3                    1                    1.0                       NaN
# 4                    1                    NaN                       NaN
#
#    basementsqft  bathroomcnt  ...  numberofstories  fireplaceflag  \
# 0           NaN          2.0  ...              NaN            NaN
# 1           NaN          3.5  ...              NaN            NaN
# 2           NaN          3.0  ...              NaN            NaN
# 3           NaN          2.0  ...              NaN            NaN
# 4           NaN          2.5  ...              2.0            NaN
#
#    structuretaxvaluedollarcnt  taxvaluedollarcnt  assessmentyear  \
# 0                    122754.0           360170.0          2015.0
# 1                    346458.0           585529.0          2015.0
# 2                     61994.0           119906.0          2015.0
# 3                    171518.0           244880.0          2015.0
# 4                    169574.0           434551.0          2015.0
#
#    landtaxvaluedollarcnt  taxamount  taxdelinquencyflag  taxdelinquencyyear  \
# 0               237416.0    6735.88                 NaN                 NaN
# 1               239071.0   10153.02                 NaN                 NaN
# 2                57912.0   11484.48                 NaN                 NaN
# 3                73362.0    3048.74                 NaN                 NaN
# 4               264977.0    5488.96                 NaN                 NaN
#
#    censustractandblock
# 0         6.037107e+13
# 1                  NaN
# 2         6.037464e+13
# 3         6.037296e+13
# 4         6.059042e+13
#
# [5 rows x 63 columns]

# %%
train2016.shape
# Out:
# (90275, 63)

# %%
train2017.head()
# Out:
#    parcelid  logerror  transaction_year  transaction_month  transaction_day  \
# 0  14297519  0.025595              2017                 13                1
# 1  17052889  0.055619              2017                 13                1
# 2  14186244  0.005383              2017                 13                1
# 3  12177905 -0.103410              2017                 13                1
# 4  10887214  0.006940              2017                 13                1
#
#    transaction_quarter  airconditioningtypeid  architecturalstyletypeid  \
# 0                    5                    NaN                       NaN
# 1                    5                    NaN                       NaN
# 2                    5                    NaN                       NaN
# 3                    5                    NaN                       NaN
# 4                    5                    1.0                       NaN
#
#    basementsqft  bathroomcnt  ...  numberofstories  fireplaceflag  \
# 0           NaN          3.5  ...              NaN            NaN
# 1           NaN          1.0  ...              1.0            NaN
# 2           NaN          2.0  ...              1.0            NaN
# 3           NaN          3.0  ...              NaN            NaN
# 4           NaN          3.0  ...              NaN            NaN
#
#    structuretaxvaluedollarcnt  taxvaluedollarcnt  assessmentyear  \
# 0                    485713.0          1023282.0          2016.0
# 1                     88000.0           464000.0          2016.0
# 2                     85289.0           564778.0          2016.0
# 3                    108918.0           145143.0          2016.0
# 4                     73681.0           119407.0          2016.0
#
#    landtaxvaluedollarcnt  taxamount  taxdelinquencyflag  taxdelinquencyyear  \
# 0               537569.0   11013.72                 NaN                 NaN
# 1               376000.0    5672.48                 NaN                 NaN
# 2               479489.0    6488.30                 NaN                 NaN
# 3                36225.0    1777.51                 NaN                 NaN
# 4                45726.0    1533.89                 NaN                 NaN
#
#    censustractandblock
# 0         6.059063e+13
# 1         6.111001e+13
# 2         6.059022e+13
# 3         6.037300e+13
# 4         6.037124e+13
#
# [5 rows x 63 columns]

# %%
train2017.shape
# Out:
# (77613, 63)

# %% [markdown]
# <font color = blue> Now we will generate our training and test files to run the model, the training file will be all properties and train from 2016 and 2017, while for the test, we will merge the sample submission with the unique properties file: </font>

# %%
print('Concat Train 2016 & 2017 ...')
train_df = pd.concat([train2016, train2017], axis = 0)
test_df = pd.merge(sample_submission_model_1[['ParcelId']], properties2016.rename(columns = {'parcelid': 'ParcelId'}), how = 'left', on = 'ParcelId')
# Out:
# Concat Train 2016 & 2017 ...

# %%
train_df.head()
# Out:
#    parcelid  logerror  transaction_year  transaction_month  transaction_day  \
# 0  11016594    0.0276              2016                  1                1
# 1  14366692   -0.1684              2016                  1                1
# 2  12098116   -0.0040              2016                  1                1
# 3  12643413    0.0218              2016                  1                2
# 4  14432541   -0.0050              2016                  1                2
#
#    transaction_quarter  airconditioningtypeid  architecturalstyletypeid  \
# 0                    1                    1.0                       NaN
# 1                    1                    NaN                       NaN
# 2                    1                    1.0                       NaN
# 3                    1                    1.0                       NaN
# 4                    1                    NaN                       NaN
#
#    basementsqft  bathroomcnt  ...  numberofstories  fireplaceflag  \
# 0           NaN          2.0  ...              NaN            NaN
# 1           NaN          3.5  ...              NaN            NaN
# 2           NaN          3.0  ...              NaN            NaN
# 3           NaN          2.0  ...              NaN            NaN
# 4           NaN          2.5  ...              2.0            NaN
#
#    structuretaxvaluedollarcnt  taxvaluedollarcnt  assessmentyear  \
# 0                    122754.0           360170.0          2015.0
# 1                    346458.0           585529.0          2015.0
# 2                     61994.0           119906.0          2015.0
# 3                    171518.0           244880.0          2015.0
# 4                    169574.0           434551.0          2015.0
#
#    landtaxvaluedollarcnt  taxamount  taxdelinquencyflag  taxdelinquencyyear  \
# 0               237416.0    6735.88                 NaN                 NaN
# 1               239071.0   10153.02                 NaN                 NaN
# 2                57912.0   11484.48                 NaN                 NaN
# 3                73362.0    3048.74                 NaN                 NaN
# 4               264977.0    5488.96                 NaN                 NaN
#
#    censustractandblock
# 0         6.037107e+13
# 1                  NaN
# 2         6.037464e+13
# 3         6.037296e+13
# 4         6.059042e+13
#
# [5 rows x 63 columns]

# %%
train_df.shape
# Out:
# (167888, 63)

# %%
test_df.head()
# Out:
#    ParcelId  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0  10754147                    NaN                       NaN           NaN
# 1  10759547                    NaN                       NaN           NaN
# 2  10843547                    NaN                       NaN           NaN
# 3  10859147                    NaN                       NaN           NaN
# 4  10879947                    NaN                       NaN           NaN
#
#    bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  \
# 0          0.0         0.0                  NaN                    NaN
# 1          0.0         0.0                  NaN                    NaN
# 2          0.0         0.0                  NaN                    NaN
# 3          0.0         0.0                  3.0                    7.0
# 4          0.0         0.0                  4.0                    NaN
#
#    calculatedbathnbr  decktypeid  ...  numberofstories  fireplaceflag  \
# 0                NaN         NaN  ...              NaN            NaN
# 1                NaN         NaN  ...              NaN            NaN
# 2                NaN         NaN  ...              NaN            NaN
# 3                NaN         NaN  ...              1.0            NaN
# 4                NaN         NaN  ...              NaN            NaN
#
#    structuretaxvaluedollarcnt  taxvaluedollarcnt  assessmentyear  \
# 0                         NaN                9.0          2015.0
# 1                         NaN            27516.0          2015.0
# 2                    650756.0          1413387.0          2015.0
# 3                    571346.0          1156834.0          2015.0
# 4                    193796.0           433491.0          2015.0
#
#    landtaxvaluedollarcnt  taxamount  taxdelinquencyflag  taxdelinquencyyear  \
# 0                    9.0        NaN                 NaN                 NaN
# 1                27516.0        NaN                 NaN                 NaN
# 2               762631.0   20800.37                 NaN                 NaN
# 3               585488.0   14557.57                 NaN                 NaN
# 4               239695.0    5725.17                 NaN                 NaN
#
#    censustractandblock
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
# [5 rows x 58 columns]

# %%
test_df.shape
# Out:
# (2985217, 58)

# %% [markdown]
# <font color = blue> To optimize memory management, we are using garbage collections algorithms (GC), which solve reference cycles (when one or more objects are referencing each other) that reference counting cannot detect: </font>

# %%
del properties2016, properties2017, train2016, train2017
gc.collect();

# %% [markdown]
# <font color = blue> Let's do some feature engineering. We have to deal with missing values, where we will establish a threshold of 98% missing values to remove those fields, and also with features with one unique value and others that we do not want to use in our training: </font>

# %%
print('Missing data fields to remove ...')
missing_perc_thresh = 0.98
exclude_missing = []
num_rows = train_df.shape[0]
for c in train_df.columns:
    num_missing = train_df[c].isnull().sum()
    if num_missing == 0:
        continue
    missing_frac = num_missing / float(num_rows)
    if missing_frac > missing_perc_thresh:
        exclude_missing.append(c)
print(exclude_missing)
print("We exclude: %s" % len(exclude_missing))
# Out:
# Missing data fields to remove ...
# ['architecturalstyletypeid', 'basementsqft', 'buildingclasstypeid', 'decktypeid', 'finishedsquarefeet13', 'finishedsquarefeet6', 'poolsizesum', 'pooltypeid10', 'pooltypeid2', 'storytypeid', 'typeconstructiontypeid', 'yardbuildingsqft26', 'fireplaceflag']
# We exclude: 13

# %%
print ("Remove features with one unique value ...")
exclude_unique = []
for c in train_df.columns:
    num_uniques = len(train_df[c].unique())
    if train_df[c].isnull().sum() != 0:
        num_uniques -= 1
    if num_uniques == 1:
        exclude_unique.append(c)
print(exclude_unique)
print("We exclude: %s" % len(exclude_unique))
# Out:
# Remove features with one unique value ...
# ['decktypeid', 'hashottuborspa', 'poolcnt', 'pooltypeid10', 'pooltypeid2', 'pooltypeid7', 'storytypeid', 'fireplaceflag', 'taxdelinquencyflag']
# We exclude: 9

# %%
del num_rows, missing_perc_thresh
gc.collect();

# %%
print ("Define training features ...")
exclude_other = ['parcelid', 'logerror', 'propertyzoningdesc']
train_features = []
for c in train_df.columns:
    if c not in exclude_missing \
       and c not in exclude_other:
        train_features.append(c)
print(train_features)
print("We use these for training: %s" % len(train_features))
# Out:
# Define training features ...
# ['transaction_year', 'transaction_month', 'transaction_day', 'transaction_quarter', 'airconditioningtypeid', 'bathroomcnt', 'bedroomcnt', 'buildingqualitytypeid', 'calculatedbathnbr', 'finishedfloor1squarefeet', 'calculatedfinishedsquarefeet', 'finishedsquarefeet12', 'finishedsquarefeet15', 'finishedsquarefeet50', 'fips', 'fireplacecnt', 'fullbathcnt', 'garagecarcnt', 'garagetotalsqft', 'hashottuborspa', 'heatingorsystemtypeid', 'latitude', 'longitude', 'lotsizesquarefeet', 'poolcnt', 'pooltypeid7', 'propertycountylandusecode', 'propertylandusetypeid', 'rawcensustractandblock', 'regionidcity', 'regionidcounty', 'regionidneighborhood', 'regionidzip', 'roomcnt', 'threequarterbathnbr', 'unitcnt', 'yardbuildingsqft17', 'yearbuilt', 'numberofstories', 'structuretaxvaluedollarcnt', 'taxvaluedollarcnt', 'assessmentyear', 'landtaxvaluedollarcnt', 'taxamount', 'taxdelinquencyflag', 'taxdelinquencyyear', 'censustractandblock']
# We use these for training: 47

# %% [markdown]
# <font color = blue> Now we have to deal with categorical features: </font>

# %%
print ("Define categorical features ...")
cat_feature_inds = []
cat_unique_thresh = 100
for i, c in enumerate(train_features):
    num_uniques = len(train_df[c].unique())
    if num_uniques < cat_unique_thresh \
       and not 'sqft' in c \
       and not 'cnt' in c \
       and not 'nbr' in c \
       and not 'number' in c:
        cat_feature_inds.append(i)
print("Cat features are: %s" % [train_features[ind] for ind in cat_feature_inds])
# Out:
# Define categorical features ...
# Cat features are: ['transaction_year', 'transaction_month', 'transaction_day', 'transaction_quarter', 'airconditioningtypeid', 'buildingqualitytypeid', 'fips', 'hashottuborspa', 'heatingorsystemtypeid', 'pooltypeid7', 'propertycountylandusecode', 'propertylandusetypeid', 'regionidcounty', 'assessmentyear', 'taxdelinquencyflag', 'taxdelinquencyyear']

# %% [markdown]
# <font color = blue> As we are going to use a tree based model, we will replace NaN values by '-999' so they do not interfere with proper data: </font>

# %%
print ("Replacing NaN values by -999 ...")
train_df.fillna(-999, inplace=True)
test_df.fillna(-999, inplace=True)
# Out:
# Replacing NaN values by -999 ...

# %%
print ("Training model 2: Cat boost ...")
X_train = train_df[train_features]
y_train = train_df.logerror
print(X_train.shape, y_train.shape)

test_df['transactiondate'] = pd.Timestamp('2016-12-01') 
test_df = add_date_features(test_df)
X_test = test_df[train_features]
print(X_test.shape)
# Out:
# Training model 2: Cat boost ...
# (167888, 47) (167888,)
# (2985217, 47)

# %%
y_pred = 0.0
model = CatBoostRegressor(
    iterations = 630, learning_rate = 0.02,
    depth = 6, l2_leaf_reg = 3,
    loss_function = 'MAE',
    eval_metric = 'MAE',
    random_seed = i)
model.fit(
    X_train, y_train,
    cat_features = cat_feature_inds)
y_pred += model.predict(X_test)
# Out:
# 0:	learn: 0.0690033	total: 364ms	remaining: 3m 48s
# 1:	learn: 0.0688482	total: 896ms	remaining: 4m 41s
# 2:	learn: 0.0687358	total: 1.28s	remaining: 4m 28s
# 3:	learn: 0.0686621	total: 1.55s	remaining: 4m 2s
# 4:	learn: 0.0686184	total: 1.84s	remaining: 3m 50s
# 5:	learn: 0.0685601	total: 2.2s	remaining: 3m 49s
# 6:	learn: 0.0685266	total: 2.55s	remaining: 3m 47s
# 7:	learn: 0.0684977	total: 2.92s	remaining: 3m 46s
# 8:	learn: 0.0684712	total: 3.71s	remaining: 4m 16s
# 9:	learn: 0.0684501	total: 4.05s	remaining: 4m 11s
# 191:	learn: 0.0676346	total: 59.2s	remaining: 2m 15s
# 192:	learn: 0.0676335	total: 59.4s	remaining: 2m 14s
# 193:	learn: 0.0676326	total: 59.7s	remaining: 2m 14s
# 194:	learn: 0.0676315	total: 59.9s	remaining: 2m 13s
# 195:	learn: 0.0676294	total: 1m	remaining: 2m 13s
# 196:	learn: 0.0676286	total: 1m	remaining: 2m 12s
# 197:	learn: 0.0676265	total: 1m	remaining: 2m 12s
# 198:	learn: 0.0676255	total: 1m	remaining: 2m 11s
# 199:	learn: 0.0676236	total: 1m 1s	remaining: 2m 11s
# 200:	learn: 0.0676209	total: 1m 1s	remaining: 2m 11s
# 201:	learn: 0.0676197	total: 1m 1s	remaining: 2m 10s
# 202:	learn: 0.0676187	total: 1m 1s	remaining: 2m 10s
# 203:	learn: 0.0676135	total: 1m 2s	remaining: 2m 9s
# 204:	learn: 0.0676117	total: 1m 2s	remaining: 2m 9s
# 205:	learn: 0.0676111	total: 1m 2s	remaining: 2m 9s
# 206:	learn: 0.0676092	total: 1m 2s	remaining: 2m 8s
# 207:	learn: 0.0676081	total: 1m 3s	remaining: 2m 8s
# 208:	learn: 0.0676063	total: 1m 3s	remaining: 2m 7s
# 209:	learn: 0.0676057	total: 1m 3s	remaining: 2m 7s
# 210:	learn: 0.0676035	total: 1m 4s	remaining: 2m 7s
# 211:	learn: 0.0676024	total: 1m 4s	remaining: 2m 6s
# 212:	learn: 0.0676002	total: 1m 4s	remaining: 2m 6s
# 213:	learn: 0.0675975	total: 1m 5s	remaining: 2m 6s
# 214:	learn: 0.0675950	total: 1m 5s	remaining: 2m 7s
# 215:	learn: 0.0675944	total: 1m 6s	remaining: 2m 6s
# 216:	learn: 0.0675935	total: 1m 6s	remaining: 2m 6s
# 217:	learn: 0.0675901	total: 1m 6s	remaining: 2m 6s
# 218:	learn: 0.0675887	total: 1m 7s	remaining: 2m 5s
# 219:	learn: 0.0675864	total: 1m 7s	remaining: 2m 5s
# 220:	learn: 0.0675836	total: 1m 7s	remaining: 2m 5s
# 221:	learn: 0.0675816	total: 1m 7s	remaining: 2m 4s
# 222:	learn: 0.0675768	total: 1m 8s	remaining: 2m 4s
# 223:	learn: 0.0675752	total: 1m 8s	remaining: 2m 3s
# 224:	learn: 0.0675743	total: 1m 8s	remaining: 2m 3s
# 225:	learn: 0.0675734	total: 1m 8s	remaining: 2m 3s
# 226:	learn: 0.0675713	total: 1m 9s	remaining: 2m 2s
# 227:	learn: 0.0675668	total: 1m 9s	remaining: 2m 2s
# 228:	learn: 0.0675652	total: 1m 9s	remaining: 2m 2s
# 229:	learn: 0.0675593	total: 1m 9s	remaining: 2m 1s
# 230:	learn: 0.0675583	total: 1m 10s	remaining: 2m 1s
# 231:	learn: 0.0675544	total: 1m 10s	remaining: 2m
# 232:	learn: 0.0675514	total: 1m 10s	remaining: 2m
# 233:	learn: 0.0675480	total: 1m 10s	remaining: 2m
# 234:	learn: 0.0675459	total: 1m 11s	remaining: 1m 59s
# 235:	learn: 0.0675449	total: 1m 11s	remaining: 1m 59s
# 324:	learn: 0.0674089	total: 1m 36s	remaining: 1m 30s
# 325:	learn: 0.0674082	total: 1m 36s	remaining: 1m 30s
# 326:	learn: 0.0674076	total: 1m 37s	remaining: 1m 30s
# 327:	learn: 0.0674060	total: 1m 37s	remaining: 1m 29s
# 328:	learn: 0.0674060	total: 1m 37s	remaining: 1m 29s
# 329:	learn: 0.0674033	total: 1m 37s	remaining: 1m 29s
# 330:	learn: 0.0674014	total: 1m 38s	remaining: 1m 28s
# 331:	learn: 0.0673994	total: 1m 38s	remaining: 1m 28s
# 332:	learn: 0.0673981	total: 1m 38s	remaining: 1m 28s
# 333:	learn: 0.0673969	total: 1m 38s	remaining: 1m 27s
# 334:	learn: 0.0673959	total: 1m 39s	remaining: 1m 27s
# 335:	learn: 0.0673908	total: 1m 39s	remaining: 1m 27s
# 336:	learn: 0.0673897	total: 1m 39s	remaining: 1m 26s
# 337:	learn: 0.0673889	total: 1m 39s	remaining: 1m 26s
# 338:	learn: 0.0673852	total: 1m 40s	remaining: 1m 26s
# 339:	learn: 0.0673842	total: 1m 40s	remaining: 1m 25s
# 340:	learn: 0.0673835	total: 1m 40s	remaining: 1m 25s
# 341:	learn: 0.0673830	total: 1m 40s	remaining: 1m 24s
# 342:	learn: 0.0673816	total: 1m 41s	remaining: 1m 24s
# 343:	learn: 0.0673794	total: 1m 41s	remaining: 1m 24s
# 344:	learn: 0.0673767	total: 1m 41s	remaining: 1m 24s
# 345:	learn: 0.0673761	total: 1m 41s	remaining: 1m 23s
# 346:	learn: 0.0673756	total: 1m 42s	remaining: 1m 23s
# 347:	learn: 0.0673750	total: 1m 42s	remaining: 1m 23s
# 348:	learn: 0.0673747	total: 1m 42s	remaining: 1m 22s
# 349:	learn: 0.0673739	total: 1m 42s	remaining: 1m 22s
# 350:	learn: 0.0673739	total: 1m 43s	remaining: 1m 21s
# 351:	learn: 0.0673735	total: 1m 43s	remaining: 1m 21s
# 352:	learn: 0.0673732	total: 1m 43s	remaining: 1m 21s
# 353:	learn: 0.0673720	total: 1m 43s	remaining: 1m 20s
# 354:	learn: 0.0673701	total: 1m 44s	remaining: 1m 20s
# 355:	learn: 0.0673700	total: 1m 44s	remaining: 1m 20s
# 356:	learn: 0.0673695	total: 1m 44s	remaining: 1m 19s
# 357:	learn: 0.0673694	total: 1m 44s	remaining: 1m 19s
# 358:	learn: 0.0673685	total: 1m 44s	remaining: 1m 19s
# 359:	learn: 0.0673662	total: 1m 45s	remaining: 1m 18s
# 360:	learn: 0.0673656	total: 1m 45s	remaining: 1m 18s
# 361:	learn: 0.0673651	total: 1m 45s	remaining: 1m 18s
# 362:	learn: 0.0673629	total: 1m 45s	remaining: 1m 17s
# 363:	learn: 0.0673599	total: 1m 46s	remaining: 1m 17s
# 364:	learn: 0.0673566	total: 1m 47s	remaining: 1m 17s
# 365:	learn: 0.0673562	total: 1m 47s	remaining: 1m 17s
# 366:	learn: 0.0673545	total: 1m 47s	remaining: 1m 17s
# 367:	learn: 0.0673536	total: 1m 48s	remaining: 1m 16s
# 368:	learn: 0.0673533	total: 1m 48s	remaining: 1m 16s
# 369:	learn: 0.0673525	total: 1m 48s	remaining: 1m 16s
# 370:	learn: 0.0673513	total: 1m 48s	remaining: 1m 15s
# 371:	learn: 0.0673482	total: 1m 49s	remaining: 1m 15s
# 372:	learn: 0.0673479	total: 1m 49s	remaining: 1m 15s
# 373:	learn: 0.0673470	total: 1m 49s	remaining: 1m 15s
# 374:	learn: 0.0673429	total: 1m 49s	remaining: 1m 14s
# 375:	learn: 0.0673421	total: 1m 50s	remaining: 1m 14s
# 376:	learn: 0.0673404	total: 1m 50s	remaining: 1m 14s
# 377:	learn: 0.0673400	total: 1m 50s	remaining: 1m 13s
# 378:	learn: 0.0673392	total: 1m 50s	remaining: 1m 13s
# 379:	learn: 0.0673378	total: 1m 51s	remaining: 1m 13s
# 380:	learn: 0.0673357	total: 1m 51s	remaining: 1m 12s
# 381:	learn: 0.0673351	total: 1m 51s	remaining: 1m 12s
# 382:	learn: 0.0673346	total: 1m 51s	remaining: 1m 12s
# 383:	learn: 0.0673316	total: 1m 52s	remaining: 1m 11s
# 384:	learn: 0.0673301	total: 1m 52s	remaining: 1m 11s
# 385:	learn: 0.0673295	total: 1m 52s	remaining: 1m 11s
# 386:	learn: 0.0673282	total: 1m 52s	remaining: 1m 10s
# 387:	learn: 0.0673266	total: 1m 53s	remaining: 1m 10s
# 388:	learn: 0.0673264	total: 1m 53s	remaining: 1m 10s
# 389:	learn: 0.0673252	total: 1m 53s	remaining: 1m 9s
# 390:	learn: 0.0673223	total: 1m 53s	remaining: 1m 9s
# 391:	learn: 0.0673216	total: 1m 54s	remaining: 1m 9s
# 392:	learn: 0.0673216	total: 1m 54s	remaining: 1m 8s
# 393:	learn: 0.0673193	total: 1m 54s	remaining: 1m 8s
# 394:	learn: 0.0673174	total: 1m 54s	remaining: 1m 8s
# 395:	learn: 0.0673167	total: 1m 54s	remaining: 1m 7s
# 396:	learn: 0.0673162	total: 1m 55s	remaining: 1m 7s
# 397:	learn: 0.0673155	total: 1m 55s	remaining: 1m 7s
# 398:	learn: 0.0673153	total: 1m 55s	remaining: 1m 6s
# 399:	learn: 0.0673122	total: 1m 55s	remaining: 1m 6s
# 400:	learn: 0.0673103	total: 1m 56s	remaining: 1m 6s
# 401:	learn: 0.0673084	total: 1m 56s	remaining: 1m 6s
# 402:	learn: 0.0673063	total: 1m 56s	remaining: 1m 5s
# 403:	learn: 0.0673058	total: 1m 57s	remaining: 1m 5s
# 404:	learn: 0.0673048	total: 1m 58s	remaining: 1m 5s
# 405:	learn: 0.0673036	total: 1m 58s	remaining: 1m 5s
# 406:	learn: 0.0673026	total: 1m 58s	remaining: 1m 4s
# 407:	learn: 0.0673023	total: 1m 58s	remaining: 1m 4s
# 408:	learn: 0.0673023	total: 1m 58s	remaining: 1m 4s
# 409:	learn: 0.0673005	total: 1m 59s	remaining: 1m 3s
# 410:	learn: 0.0673000	total: 1m 59s	remaining: 1m 3s
# 594:	learn: 0.0670635	total: 2m 50s	remaining: 10.1s
# 595:	learn: 0.0670624	total: 2m 51s	remaining: 9.77s
# 596:	learn: 0.0670587	total: 2m 51s	remaining: 9.48s
# 597:	learn: 0.0670556	total: 2m 51s	remaining: 9.19s
# 598:	learn: 0.0670521	total: 2m 52s	remaining: 8.9s
# 599:	learn: 0.0670506	total: 2m 52s	remaining: 8.62s
# 600:	learn: 0.0670499	total: 2m 52s	remaining: 8.33s
# 601:	learn: 0.0670495	total: 2m 52s	remaining: 8.04s
# 602:	learn: 0.0670483	total: 2m 53s	remaining: 7.75s
# 603:	learn: 0.0670472	total: 2m 53s	remaining: 7.46s
# 604:	learn: 0.0670444	total: 2m 53s	remaining: 7.17s
# 605:	learn: 0.0670429	total: 2m 53s	remaining: 6.88s
# 606:	learn: 0.0670426	total: 2m 54s	remaining: 6.6s
# 607:	learn: 0.0670417	total: 2m 54s	remaining: 6.31s
# 608:	learn: 0.0670402	total: 2m 54s	remaining: 6.02s
# 609:	learn: 0.0670377	total: 2m 54s	remaining: 5.73s
# 610:	learn: 0.0670367	total: 2m 55s	remaining: 5.45s
# 611:	learn: 0.0670317	total: 2m 55s	remaining: 5.16s
# 612:	learn: 0.0670281	total: 2m 55s	remaining: 4.87s
# 613:	learn: 0.0670271	total: 2m 55s	remaining: 4.58s
# 614:	learn: 0.0670248	total: 2m 56s	remaining: 4.3s
# 615:	learn: 0.0670223	total: 2m 56s	remaining: 4.01s
# 616:	learn: 0.0670214	total: 2m 56s	remaining: 3.72s
# 617:	learn: 0.0670170	total: 2m 57s	remaining: 3.44s
# 618:	learn: 0.0670166	total: 2m 57s	remaining: 3.15s
# 619:	learn: 0.0670147	total: 2m 57s	remaining: 2.86s
# 620:	learn: 0.0670124	total: 2m 57s	remaining: 2.58s
# 621:	learn: 0.0670105	total: 2m 58s	remaining: 2.29s
# 622:	learn: 0.0670095	total: 2m 58s	remaining: 2s
# 623:	learn: 0.0670091	total: 2m 58s	remaining: 1.72s
# 624:	learn: 0.0670084	total: 2m 59s	remaining: 1.44s
# 625:	learn: 0.0670047	total: 2m 59s	remaining: 1.15s
# 626:	learn: 0.0670032	total: 3m	remaining: 862ms
# 627:	learn: 0.0670028	total: 3m	remaining: 575ms
# 628:	learn: 0.0670026	total: 3m	remaining: 287ms
# 629:	learn: 0.0670012	total: 3m 1s	remaining: 0us

# %%
submission = pd.DataFrame({
    'ParcelId': test_df['ParcelId'],
})
test_dates = {
    '201710': pd.Timestamp('2017-09-30')
}
for label, test_date in test_dates.items():
    print("Predicting for: %s ... " % (label))
    submission[label] = y_pred
    
submission.to_csv(data_path + 'Model_2_CatBoost.csv', float_format='%.6f',index=False)
# Out:
# Predicting for: 201710 ...

# %%
predictions_model_1 = pd.read_csv(data_path + 'Model_2_CatBoost.csv')
predictions_model_1.head()
# Out:
#    ParcelId    201710
# 0  10754147  0.008218
# 1  10759547 -0.006502
# 2  10843547  0.033699
# 3  10859147  0.026486
# 4  10879947  0.002748
