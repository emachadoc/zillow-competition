# %% [markdown]
# ## CAT BOOST REGRESSOR

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
color = sns.color_palette()
import zipfile
import re
from scipy import stats
from catboost import CatBoostRegressor
from tqdm import tqdm
import gc
import datetime as dt

# %% [markdown]
# <font color = blue> Once we have imported the necessary libraries, we are going to define our data path and then, load the data: </font>

# %%
data_path = './data/'

# %%
print('Loading Properties ...')
properties2016 = pd.read_csv(data_path + 'properties_2016.csv', low_memory = False)
properties2017 = pd.read_csv(data_path + 'properties_2017.csv', low_memory = False)
# Out:
# Loading Properties ...

# %%
properties2016.head()
# Out:
#    parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0  10754147                    NaN                       NaN           NaN
# 1  10759547                    NaN                       NaN           NaN
# 2  10843547                    NaN                       NaN           NaN
# 3  10859147                    NaN                       NaN           NaN
# 4  10879947                    NaN                       NaN           NaN
#
#    bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  \
# 0          0.0         0.0                  NaN                    NaN
# 1          0.0         0.0                  NaN                    NaN
# 2          0.0         0.0                  NaN                    NaN
# 3          0.0         0.0                  3.0                    7.0
# 4          0.0         0.0                  4.0                    NaN
#
#    calculatedbathnbr  decktypeid  ...  numberofstories  fireplaceflag  \
# 0                NaN         NaN  ...              NaN            NaN
# 1                NaN         NaN  ...              NaN            NaN
# 2                NaN         NaN  ...              NaN            NaN
# 3                NaN         NaN  ...              1.0            NaN
# 4                NaN         NaN  ...              NaN            NaN
#
#    structuretaxvaluedollarcnt  taxvaluedollarcnt  assessmentyear  \
# 0                         NaN                9.0          2015.0
# 1                         NaN            27516.0          2015.0
# 2                    650756.0          1413387.0          2015.0
# 3                    571346.0          1156834.0          2015.0
# 4                    193796.0           433491.0          2015.0
#
#    landtaxvaluedollarcnt  taxamount  taxdelinquencyflag  taxdelinquencyyear  \
# 0                    9.0        NaN                 NaN                 NaN
# 1                27516.0        NaN                 NaN                 NaN
# 2               762631.0   20800.37                 NaN                 NaN
# 3               585488.0   14557.57                 NaN                 NaN
# 4               239695.0    5725.17                 NaN                 NaN
#
#    censustractandblock
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
# [5 rows x 58 columns]

# %%
properties2016.shape
# Out:
# (2985217, 58)

# %%
properties2017.head()
# Out:
#    parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0  10754147                    NaN                       NaN           NaN
# 1  10759547                    NaN                       NaN           NaN
# 2  10843547                    NaN                       NaN           NaN
# 3  10859147                    NaN                       NaN           NaN
# 4  10879947                    NaN                       NaN           NaN
#
#    bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  \
# 0          0.0         0.0                  NaN                    NaN
# 1          0.0         0.0                  NaN                    NaN
# 2          0.0         0.0                  5.0                    NaN
# 3          0.0         0.0                  3.0                    6.0
# 4          0.0         0.0                  4.0                    NaN
#
#    calculatedbathnbr  decktypeid  ...  numberofstories  fireplaceflag  \
# 0                NaN         NaN  ...              NaN            NaN
# 1                NaN         NaN  ...              NaN            NaN
# 2                NaN         NaN  ...              1.0            NaN
# 3                NaN         NaN  ...              1.0            NaN
# 4                NaN         NaN  ...              1.0            NaN
#
#    structuretaxvaluedollarcnt  taxvaluedollarcnt  assessmentyear  \
# 0                         NaN                9.0          2016.0
# 1                         NaN            27516.0          2015.0
# 2                    660680.0          1434941.0          2016.0
# 3                    580059.0          1174475.0          2016.0
# 4                    196751.0           440101.0          2016.0
#
#    landtaxvaluedollarcnt  taxamount  taxdelinquencyflag  taxdelinquencyyear  \
# 0                    9.0        NaN                 NaN                 NaN
# 1                27516.0        NaN                 NaN                 NaN
# 2               774261.0   20800.37                 NaN                 NaN
# 3               594416.0   14557.57                 NaN                 NaN
# 4               243350.0    5725.17                 NaN                 NaN
#
#    censustractandblock
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
# [5 rows x 58 columns]

# %%
properties2017.shape
# Out:
# (2985217, 58)

# %% [markdown]
# <font color = blue> We are going to specify the parameter 'parse_dates' to make the column 'transactiondate' in train files date formatted: </font>

# %%
print('Loading Train ...')
train2016 = pd.read_csv(data_path + 'train_2016_v2.csv', parse_dates=['transactiondate'], low_memory=False)
train2017 = pd.read_csv(data_path + 'train_2017.csv', parse_dates=['transactiondate'], low_memory=False)
# Out:
# Loading Train ...

# %%
train2016.shape
# Out:
# (90275, 3)

# %%
train2017.shape
# Out:
# (77613, 3)

# %%
train2016.head()
# Out:
#    parcelid  logerror transactiondate
# 0  11016594    0.0276      2016-01-01
# 1  14366692   -0.1684      2016-01-01
# 2  12098116   -0.0040      2016-01-01
# 3  12643413    0.0218      2016-01-02
# 4  14432541   -0.0050      2016-01-02

# %% [markdown]
# <font color = blue> Now we are going to parse dates to get one column for year, one for month, one for day and one for quarter: </font>

# %%
def add_date_features(df):
    df["transaction_year"] = df["transactiondate"].dt.year
    df["transaction_month"] = (df["transactiondate"].dt.year - 2016)*12 + df["transactiondate"].dt.month
    df["transaction_day"] = df["transactiondate"].dt.day
    df["transaction_quarter"] = (df["transactiondate"].dt.year - 2016)*4 + df["transactiondate"].dt.quarter
    df.drop(["transactiondate"], inplace=True, axis=1)
    return df

# %%
train2016 = add_date_features(train2016)
train2017 = add_date_features(train2017)

# %%
train2016.head()
# Out:
#    parcelid  logerror  transaction_year  transaction_month  transaction_day  \
# 0  11016594    0.0276              2016                  1                1
# 1  14366692   -0.1684              2016                  1                1
# 2  12098116   -0.0040              2016                  1                1
# 3  12643413    0.0218              2016                  1                2
# 4  14432541   -0.0050              2016                  1                2
#
#    transaction_quarter
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    1

# %%
print('Loading Sample ...')
sample_submission = pd.read_csv(data_path + 'sample_submission.csv', low_memory = False)
# Out:
# Loading Sample ...

# %% [markdown]
# <font color = blue> Our sample submission will be a file with the parcel id for each property and six prediction columns for different dates (last 2016 quarter and last 2017 quarter): </font>

# %%
sample_submission.head()
# Out:
#    ParcelId  201610  201611  201612  201710  201711  201712
# 0  10754147       0       0       0       0       0       0
# 1  10759547       0       0       0       0       0       0
# 2  10843547       0       0       0       0       0       0
# 3  10859147       0       0       0       0       0       0
# 4  10879947       0       0       0       0       0       0

# %% [markdown]
# <font color = blue> As we are going to apply the first model, cat boost, to the column for 201611 predictions, we remove the other columns: </font>

# %%
sample_submission_model_3 = sample_submission.drop(columns = ['201610', '201612', '201710', '201711', '201712'])
sample_submission_model_3.head()
# Out:
#    ParcelId  201611
# 0  10754147       0
# 1  10759547       0
# 2  10843547       0
# 3  10859147       0
# 4  10879947       0

# %% [markdown]
# <font color = blue> We will merge properties and train files to get all data grouped: </font>

# %%
print('Merging Train with Properties ...')
train2016 = pd.merge(train2016, properties2016, how = 'left', on = 'parcelid')
train2017 = pd.merge(train2017, properties2017, how = 'left', on = 'parcelid')
# Out:
# Merging Train with Properties ...

# %%
train2016.head()
# Out:
#    parcelid  logerror  transaction_year  transaction_month  transaction_day  \
# 0  11016594    0.0276              2016                  1                1
# 1  14366692   -0.1684              2016                  1                1
# 2  12098116   -0.0040              2016                  1                1
# 3  12643413    0.0218              2016                  1                2
# 4  14432541   -0.0050              2016                  1                2
#
#    transaction_quarter  airconditioningtypeid  architecturalstyletypeid  \
# 0                    1                    1.0                       NaN
# 1                    1                    NaN                       NaN
# 2                    1                    1.0                       NaN
# 3                    1                    1.0                       NaN
# 4                    1                    NaN                       NaN
#
#    basementsqft  bathroomcnt  ...  numberofstories  fireplaceflag  \
# 0           NaN          2.0  ...              NaN            NaN
# 1           NaN          3.5  ...              NaN            NaN
# 2           NaN          3.0  ...              NaN            NaN
# 3           NaN          2.0  ...              NaN            NaN
# 4           NaN          2.5  ...              2.0            NaN
#
#    structuretaxvaluedollarcnt  taxvaluedollarcnt  assessmentyear  \
# 0                    122754.0           360170.0          2015.0
# 1                    346458.0           585529.0          2015.0
# 2                     61994.0           119906.0          2015.0
# 3                    171518.0           244880.0          2015.0
# 4                    169574.0           434551.0          2015.0
#
#    landtaxvaluedollarcnt  taxamount  taxdelinquencyflag  taxdelinquencyyear  \
# 0               237416.0    6735.88                 NaN                 NaN
# 1               239071.0   10153.02                 NaN                 NaN
# 2                57912.0   11484.48                 NaN                 NaN
# 3                73362.0    3048.74                 NaN                 NaN
# 4               264977.0    5488.96                 NaN                 NaN
#
#    censustractandblock
# 0         6.037107e+13
# 1                  NaN
# 2         6.037464e+13
# 3         6.037296e+13
# 4         6.059042e+13
#
# [5 rows x 63 columns]

# %%
train2016.shape
# Out:
# (90275, 63)

# %%
train2017.head()
# Out:
#    parcelid  logerror  transaction_year  transaction_month  transaction_day  \
# 0  14297519  0.025595              2017                 13                1
# 1  17052889  0.055619              2017                 13                1
# 2  14186244  0.005383              2017                 13                1
# 3  12177905 -0.103410              2017                 13                1
# 4  10887214  0.006940              2017                 13                1
#
#    transaction_quarter  airconditioningtypeid  architecturalstyletypeid  \
# 0                    5                    NaN                       NaN
# 1                    5                    NaN                       NaN
# 2                    5                    NaN                       NaN
# 3                    5                    NaN                       NaN
# 4                    5                    1.0                       NaN
#
#    basementsqft  bathroomcnt  ...  numberofstories  fireplaceflag  \
# 0           NaN          3.5  ...              NaN            NaN
# 1           NaN          1.0  ...              1.0            NaN
# 2           NaN          2.0  ...              1.0            NaN
# 3           NaN          3.0  ...              NaN            NaN
# 4           NaN          3.0  ...              NaN            NaN
#
#    structuretaxvaluedollarcnt  taxvaluedollarcnt  assessmentyear  \
# 0                    485713.0          1023282.0          2016.0
# 1                     88000.0           464000.0          2016.0
# 2                     85289.0           564778.0          2016.0
# 3                    108918.0           145143.0          2016.0
# 4                     73681.0           119407.0          2016.0
#
#    landtaxvaluedollarcnt  taxamount  taxdelinquencyflag  taxdelinquencyyear  \
# 0               537569.0   11013.72                 NaN                 NaN
# 1               376000.0    5672.48                 NaN                 NaN
# 2               479489.0    6488.30                 NaN                 NaN
# 3                36225.0    1777.51                 NaN                 NaN
# 4                45726.0    1533.89                 NaN                 NaN
#
#    censustractandblock
# 0         6.059063e+13
# 1         6.111001e+13
# 2         6.059022e+13
# 3         6.037300e+13
# 4         6.037124e+13
#
# [5 rows x 63 columns]

# %%
train2017.shape
# Out:
# (77613, 63)

# %% [markdown]
# <font color = blue> As we should not use the 2016 tax values when predicting log errors against the 2016 log errors, we will omit this information for the 2016 predicitons columns: </font>

# %%
print('Tax Features 2017  ...')
train2017.iloc[:, train2017.columns.str.startswith('tax')] = np.nan
train2017.iloc[:, train2017.columns.str.endswith('taxvaluedollarcnt')] = np.nan
# Out:
# Tax Features 2017  ...

# %%
train2017.head()
# Out:
#    parcelid  logerror  transaction_year  transaction_month  transaction_day  \
# 0  14297519  0.025595              2017                 13                1
# 1  17052889  0.055619              2017                 13                1
# 2  14186244  0.005383              2017                 13                1
# 3  12177905 -0.103410              2017                 13                1
# 4  10887214  0.006940              2017                 13                1
#
#    transaction_quarter  airconditioningtypeid  architecturalstyletypeid  \
# 0                    5                    NaN                       NaN
# 1                    5                    NaN                       NaN
# 2                    5                    NaN                       NaN
# 3                    5                    NaN                       NaN
# 4                    5                    1.0                       NaN
#
#    basementsqft  bathroomcnt  ...  numberofstories  fireplaceflag  \
# 0           NaN          3.5  ...              NaN            NaN
# 1           NaN          1.0  ...              1.0            NaN
# 2           NaN          2.0  ...              1.0            NaN
# 3           NaN          3.0  ...              NaN            NaN
# 4           NaN          3.0  ...              NaN            NaN
#
#    structuretaxvaluedollarcnt  taxvaluedollarcnt  assessmentyear  \
# 0                         NaN                NaN          2016.0
# 1                         NaN                NaN          2016.0
# 2                         NaN                NaN          2016.0
# 3                         NaN                NaN          2016.0
# 4                         NaN                NaN          2016.0
#
#    landtaxvaluedollarcnt  taxamount  taxdelinquencyflag  taxdelinquencyyear  \
# 0                    NaN        NaN                 NaN                 NaN
# 1                    NaN        NaN                 NaN                 NaN
# 2                    NaN        NaN                 NaN                 NaN
# 3                    NaN        NaN                 NaN                 NaN
# 4                    NaN        NaN                 NaN                 NaN
#
#    censustractandblock
# 0         6.059063e+13
# 1         6.111001e+13
# 2         6.059022e+13
# 3         6.037300e+13
# 4         6.037124e+13
#
# [5 rows x 63 columns]

# %% [markdown]
# <font color = blue> Now we will generate our training and test files to run the model, the training file will be all properties and train from 2016 and 2017, while for the test, we will merge the sample submission with the unique properties file: </font>

# %%
print('Concat Train 2016 & 2017 ...')
train_df = pd.concat([train2016, train2017], axis = 0)
test_df = pd.merge(sample_submission_model_3[['ParcelId']], properties2016.rename(columns = {'parcelid': 'ParcelId'}), how = 'left', on = 'ParcelId')
# Out:
# Concat Train 2016 & 2017 ...

# %%
train_df.head()
# Out:
#    parcelid  logerror  transaction_year  transaction_month  transaction_day  \
# 0  11016594    0.0276              2016                  1                1
# 1  14366692   -0.1684              2016                  1                1
# 2  12098116   -0.0040              2016                  1                1
# 3  12643413    0.0218              2016                  1                2
# 4  14432541   -0.0050              2016                  1                2
#
#    transaction_quarter  airconditioningtypeid  architecturalstyletypeid  \
# 0                    1                    1.0                       NaN
# 1                    1                    NaN                       NaN
# 2                    1                    1.0                       NaN
# 3                    1                    1.0                       NaN
# 4                    1                    NaN                       NaN
#
#    basementsqft  bathroomcnt  ...  numberofstories  fireplaceflag  \
# 0           NaN          2.0  ...              NaN            NaN
# 1           NaN          3.5  ...              NaN            NaN
# 2           NaN          3.0  ...              NaN            NaN
# 3           NaN          2.0  ...              NaN            NaN
# 4           NaN          2.5  ...              2.0            NaN
#
#    structuretaxvaluedollarcnt  taxvaluedollarcnt  assessmentyear  \
# 0                    122754.0           360170.0          2015.0
# 1                    346458.0           585529.0          2015.0
# 2                     61994.0           119906.0          2015.0
# 3                    171518.0           244880.0          2015.0
# 4                    169574.0           434551.0          2015.0
#
#    landtaxvaluedollarcnt  taxamount  taxdelinquencyflag  taxdelinquencyyear  \
# 0               237416.0    6735.88                 NaN                 NaN
# 1               239071.0   10153.02                 NaN                 NaN
# 2                57912.0   11484.48                 NaN                 NaN
# 3                73362.0    3048.74                 NaN                 NaN
# 4               264977.0    5488.96                 NaN                 NaN
#
#    censustractandblock
# 0         6.037107e+13
# 1                  NaN
# 2         6.037464e+13
# 3         6.037296e+13
# 4         6.059042e+13
#
# [5 rows x 63 columns]

# %%
train_df.shape
# Out:
# (167888, 63)

# %%
test_df.head()
# Out:
#    ParcelId  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0  10754147                    NaN                       NaN           NaN
# 1  10759547                    NaN                       NaN           NaN
# 2  10843547                    NaN                       NaN           NaN
# 3  10859147                    NaN                       NaN           NaN
# 4  10879947                    NaN                       NaN           NaN
#
#    bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  \
# 0          0.0         0.0                  NaN                    NaN
# 1          0.0         0.0                  NaN                    NaN
# 2          0.0         0.0                  NaN                    NaN
# 3          0.0         0.0                  3.0                    7.0
# 4          0.0         0.0                  4.0                    NaN
#
#    calculatedbathnbr  decktypeid  ...  numberofstories  fireplaceflag  \
# 0                NaN         NaN  ...              NaN            NaN
# 1                NaN         NaN  ...              NaN            NaN
# 2                NaN         NaN  ...              NaN            NaN
# 3                NaN         NaN  ...              1.0            NaN
# 4                NaN         NaN  ...              NaN            NaN
#
#    structuretaxvaluedollarcnt  taxvaluedollarcnt  assessmentyear  \
# 0                         NaN                9.0          2015.0
# 1                         NaN            27516.0          2015.0
# 2                    650756.0          1413387.0          2015.0
# 3                    571346.0          1156834.0          2015.0
# 4                    193796.0           433491.0          2015.0
#
#    landtaxvaluedollarcnt  taxamount  taxdelinquencyflag  taxdelinquencyyear  \
# 0                    9.0        NaN                 NaN                 NaN
# 1                27516.0        NaN                 NaN                 NaN
# 2               762631.0   20800.37                 NaN                 NaN
# 3               585488.0   14557.57                 NaN                 NaN
# 4               239695.0    5725.17                 NaN                 NaN
#
#    censustractandblock
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
# [5 rows x 58 columns]

# %%
test_df.shape
# Out:
# (2985217, 58)

# %% [markdown]
# <font color = blue> To optimize memory management, we are using garbage collections algorithms (GC), which solve reference cycles (when one or more objects are referencing each other) that reference counting cannot detect: </font>

# %%
del properties2016, properties2017, train2016, train2017
gc.collect();

# %% [markdown]
# <font color = blue> Let's do some feature engineering. We have to deal with missing values, where we will establish a threshold of 98% missing values to remove those fields, and also with features with one unique value and others that we do not want to use in our training: </font>

# %%
print('Missing data fields to remove ...')
missing_perc_thresh = 0.95
exclude_missing = []
num_rows = train_df.shape[0]
for c in train_df.columns:
    num_missing = train_df[c].isnull().sum()
    if num_missing == 0:
        continue
    missing_frac = num_missing / float(num_rows)
    if missing_frac > missing_perc_thresh:
        exclude_missing.append(c)
print(exclude_missing)
print("We exclude: %s" % len(exclude_missing))
# Out:
# Missing data fields to remove ...
# ['architecturalstyletypeid', 'basementsqft', 'buildingclasstypeid', 'decktypeid', 'finishedsquarefeet13', 'finishedsquarefeet15', 'finishedsquarefeet6', 'hashottuborspa', 'poolsizesum', 'pooltypeid10', 'pooltypeid2', 'storytypeid', 'typeconstructiontypeid', 'yardbuildingsqft17', 'yardbuildingsqft26', 'fireplaceflag', 'taxdelinquencyflag', 'taxdelinquencyyear']
# We exclude: 18

# %%
print ("Remove features with one unique value ...")
exclude_unique = []
for c in train_df.columns:
    num_uniques = len(train_df[c].unique())
    if train_df[c].isnull().sum() != 0:
        num_uniques -= 1
    if num_uniques == 1:
        exclude_unique.append(c)
print(exclude_unique)
print("We exclude: %s" % len(exclude_unique))
# Out:
# Remove features with one unique value ...
# ['decktypeid', 'hashottuborspa', 'poolcnt', 'pooltypeid10', 'pooltypeid2', 'pooltypeid7', 'storytypeid', 'fireplaceflag', 'taxdelinquencyflag']
# We exclude: 9

# %%
del num_rows, missing_perc_thresh
gc.collect();

# %%
print ("Define training features ...")
exclude_other = ['parcelid', 'logerror', 'propertyzoningdesc']
train_features = []
for c in train_df.columns:
    if c not in exclude_missing \
       and c not in exclude_other:
        train_features.append(c)
print(train_features)
print("We use these for training: %s" % len(train_features))
# Out:
# Define training features ...
# ['transaction_year', 'transaction_month', 'transaction_day', 'transaction_quarter', 'airconditioningtypeid', 'bathroomcnt', 'bedroomcnt', 'buildingqualitytypeid', 'calculatedbathnbr', 'finishedfloor1squarefeet', 'calculatedfinishedsquarefeet', 'finishedsquarefeet12', 'finishedsquarefeet50', 'fips', 'fireplacecnt', 'fullbathcnt', 'garagecarcnt', 'garagetotalsqft', 'heatingorsystemtypeid', 'latitude', 'longitude', 'lotsizesquarefeet', 'poolcnt', 'pooltypeid7', 'propertycountylandusecode', 'propertylandusetypeid', 'rawcensustractandblock', 'regionidcity', 'regionidcounty', 'regionidneighborhood', 'regionidzip', 'roomcnt', 'threequarterbathnbr', 'unitcnt', 'yearbuilt', 'numberofstories', 'structuretaxvaluedollarcnt', 'taxvaluedollarcnt', 'assessmentyear', 'landtaxvaluedollarcnt', 'taxamount', 'censustractandblock']
# We use these for training: 42

# %% [markdown]
# <font color = blue> Now we have to deal with categorical features: </font>

# %%
print ("Define categorical features ...")
cat_feature_inds = []
cat_unique_thresh = 100
for i, c in enumerate(train_features):
    num_uniques = len(train_df[c].unique())
    if num_uniques < cat_unique_thresh \
       and not 'sqft' in c \
       and not 'cnt' in c \
       and not 'nbr' in c \
       and not 'number' in c:
        cat_feature_inds.append(i)
print("Cat features are: %s" % [train_features[ind] for ind in cat_feature_inds])
# Out:
# Define categorical features ...
# Cat features are: ['transaction_year', 'transaction_month', 'transaction_day', 'transaction_quarter', 'airconditioningtypeid', 'buildingqualitytypeid', 'fips', 'heatingorsystemtypeid', 'pooltypeid7', 'propertycountylandusecode', 'propertylandusetypeid', 'regionidcounty', 'assessmentyear']

# %% [markdown]
# <font color = blue> As we are going to use a tree based model, we will replace NaN values by '-999' so they do not interfere with proper data: </font>

# %%
print ("Replacing NaN values by -999 ...")
train_df.fillna(-999, inplace=True)
test_df.fillna(-999, inplace=True)
# Out:
# Replacing NaN values by -999 ...

# %%
print ("Training model 3: Cat boost ...")
X_train = train_df[train_features]
y_train = train_df.logerror
print(X_train.shape, y_train.shape)

test_df['transactiondate'] = pd.Timestamp('2016-12-01') 
test_df = add_date_features(test_df)
X_test = test_df[train_features]
print(X_test.shape)
# Out:
# Training model 3: Cat boost ...
# (167888, 42) (167888,)
# (2985217, 42)

# %%
y_pred = 0.0
model = CatBoostRegressor(
    iterations = 720, learning_rate = 0.03,
    depth = 8, l2_leaf_reg = 5,
    loss_function = 'MAE',
    eval_metric = 'MAE',
    random_seed = i)
model.fit(
    X_train, y_train,
    cat_features = cat_feature_inds)
y_pred += model.predict(X_test)
# Out:
# 0:	learn: 0.0688886	total: 575ms	remaining: 6m 53s
# 1:	learn: 0.0686979	total: 1.1s	remaining: 6m 35s
# 2:	learn: 0.0685757	total: 1.67s	remaining: 6m 38s
# 3:	learn: 0.0684958	total: 2.34s	remaining: 6m 58s
# 4:	learn: 0.0684539	total: 2.78s	remaining: 6m 37s
# 5:	learn: 0.0684085	total: 4.21s	remaining: 8m 20s
# 6:	learn: 0.0683441	total: 4.77s	remaining: 8m 5s
# 7:	learn: 0.0683032	total: 5.24s	remaining: 7m 46s
# 8:	learn: 0.0682586	total: 5.68s	remaining: 7m 28s
# 9:	learn: 0.0682175	total: 6.22s	remaining: 7m 21s
# 10:	learn: 0.0681764	total: 6.66s	remaining: 7m 9s
# 11:	learn: 0.0681526	total: 7.06s	remaining: 6m 56s
# 12:	learn: 0.0681346	total: 7.47s	remaining: 6m 46s
# 13:	learn: 0.0681071	total: 7.89s	remaining: 6m 37s
# 14:	learn: 0.0680927	total: 8.34s	remaining: 6m 31s
# 15:	learn: 0.0680698	total: 8.8s	remaining: 6m 27s
# 16:	learn: 0.0680362	total: 9.3s	remaining: 6m 24s
# 17:	learn: 0.0680272	total: 9.71s	remaining: 6m 18s
# 18:	learn: 0.0679979	total: 10.2s	remaining: 6m 15s
# 19:	learn: 0.0679702	total: 10.6s	remaining: 6m 11s
# 20:	learn: 0.0679540	total: 11.1s	remaining: 6m 8s
# 21:	learn: 0.0679457	total: 11.5s	remaining: 6m 5s
# 22:	learn: 0.0679264	total: 11.9s	remaining: 6m 1s
# 23:	learn: 0.0679079	total: 12.4s	remaining: 6m
# 24:	learn: 0.0678992	total: 13s	remaining: 6m
# 25:	learn: 0.0678848	total: 13.4s	remaining: 5m 58s
# 26:	learn: 0.0678634	total: 14.4s	remaining: 6m 8s
# 27:	learn: 0.0678453	total: 14.9s	remaining: 6m 7s
# 28:	learn: 0.0678296	total: 15.3s	remaining: 6m 3s
# 552:	learn: 0.0655310	total: 5m 4s	remaining: 1m 31s
# 553:	learn: 0.0655297	total: 5m 4s	remaining: 1m 31s
# 554:	learn: 0.0655241	total: 5m 5s	remaining: 1m 30s
# 555:	learn: 0.0655156	total: 5m 5s	remaining: 1m 30s
# 556:	learn: 0.0655116	total: 5m 6s	remaining: 1m 29s
# 557:	learn: 0.0655103	total: 5m 6s	remaining: 1m 29s
# 558:	learn: 0.0655081	total: 5m 7s	remaining: 1m 28s
# 559:	learn: 0.0655026	total: 5m 7s	remaining: 1m 27s
# 560:	learn: 0.0654951	total: 5m 8s	remaining: 1m 27s
# 561:	learn: 0.0654908	total: 5m 8s	remaining: 1m 26s
# 562:	learn: 0.0654779	total: 5m 9s	remaining: 1m 26s
# 563:	learn: 0.0654737	total: 5m 10s	remaining: 1m 25s
# 564:	learn: 0.0654661	total: 5m 11s	remaining: 1m 25s
# 565:	learn: 0.0654631	total: 5m 11s	remaining: 1m 24s
# 566:	learn: 0.0654620	total: 5m 11s	remaining: 1m 24s
# 567:	learn: 0.0654607	total: 5m 12s	remaining: 1m 23s
# 568:	learn: 0.0654542	total: 5m 12s	remaining: 1m 23s
# 569:	learn: 0.0654500	total: 5m 13s	remaining: 1m 22s
# 570:	learn: 0.0654407	total: 5m 13s	remaining: 1m 21s
# 571:	learn: 0.0654373	total: 5m 14s	remaining: 1m 21s
# 572:	learn: 0.0654305	total: 5m 14s	remaining: 1m 20s
# 573:	learn: 0.0654234	total: 5m 15s	remaining: 1m 20s
# 574:	learn: 0.0654186	total: 5m 15s	remaining: 1m 19s
# 575:	learn: 0.0654155	total: 5m 16s	remaining: 1m 19s
# 576:	learn: 0.0654062	total: 5m 16s	remaining: 1m 18s
# 577:	learn: 0.0653990	total: 5m 16s	remaining: 1m 17s
# 578:	learn: 0.0653872	total: 5m 17s	remaining: 1m 17s
# 579:	learn: 0.0653856	total: 5m 18s	remaining: 1m 16s
# 580:	learn: 0.0653813	total: 5m 18s	remaining: 1m 16s
# 581:	learn: 0.0653774	total: 5m 19s	remaining: 1m 15s
# 582:	learn: 0.0653681	total: 5m 19s	remaining: 1m 15s
# 583:	learn: 0.0653643	total: 5m 20s	remaining: 1m 14s
# 584:	learn: 0.0653582	total: 5m 21s	remaining: 1m 14s
# 585:	learn: 0.0653534	total: 5m 21s	remaining: 1m 13s
# 586:	learn: 0.0653462	total: 5m 22s	remaining: 1m 13s
# 587:	learn: 0.0653410	total: 5m 23s	remaining: 1m 12s
# 588:	learn: 0.0653377	total: 5m 24s	remaining: 1m 12s
# 589:	learn: 0.0653306	total: 5m 24s	remaining: 1m 11s
# 590:	learn: 0.0653202	total: 5m 25s	remaining: 1m 11s
# 591:	learn: 0.0653189	total: 5m 26s	remaining: 1m 10s
# 592:	learn: 0.0653156	total: 5m 27s	remaining: 1m 10s
# 593:	learn: 0.0653144	total: 5m 27s	remaining: 1m 9s
# 594:	learn: 0.0653092	total: 5m 28s	remaining: 1m 9s
# 595:	learn: 0.0653073	total: 5m 29s	remaining: 1m 8s
# 596:	learn: 0.0653033	total: 5m 30s	remaining: 1m 8s
# 597:	learn: 0.0652967	total: 5m 31s	remaining: 1m 7s
# 598:	learn: 0.0652940	total: 5m 32s	remaining: 1m 7s
# 599:	learn: 0.0652932	total: 5m 33s	remaining: 1m 6s
# 600:	learn: 0.0652859	total: 5m 34s	remaining: 1m 6s
# 601:	learn: 0.0652826	total: 5m 34s	remaining: 1m 5s
# 602:	learn: 0.0652759	total: 5m 35s	remaining: 1m 5s
# 603:	learn: 0.0652731	total: 5m 36s	remaining: 1m 4s
# 604:	learn: 0.0652708	total: 5m 37s	remaining: 1m 4s
# 605:	learn: 0.0652689	total: 5m 37s	remaining: 1m 3s
# 606:	learn: 0.0652651	total: 5m 38s	remaining: 1m 3s
# 607:	learn: 0.0652619	total: 5m 39s	remaining: 1m 2s
# 608:	learn: 0.0652605	total: 5m 40s	remaining: 1m 2s
# 609:	learn: 0.0652541	total: 5m 41s	remaining: 1m 1s
# 610:	learn: 0.0652507	total: 5m 42s	remaining: 1m 1s
# 611:	learn: 0.0652497	total: 5m 43s	remaining: 1m
# 612:	learn: 0.0652402	total: 5m 44s	remaining: 1m
# 613:	learn: 0.0652382	total: 5m 45s	remaining: 59.6s
# 614:	learn: 0.0652354	total: 5m 46s	remaining: 59.1s
# 615:	learn: 0.0652302	total: 5m 47s	remaining: 58.6s
# 616:	learn: 0.0652253	total: 5m 47s	remaining: 58.1s
# 617:	learn: 0.0652240	total: 5m 48s	remaining: 57.6s
# 618:	learn: 0.0652212	total: 5m 49s	remaining: 57.1s
# 619:	learn: 0.0652200	total: 5m 50s	remaining: 56.6s
# 620:	learn: 0.0652151	total: 5m 52s	remaining: 56.1s
# 621:	learn: 0.0652113	total: 5m 53s	remaining: 55.6s
# 622:	learn: 0.0652091	total: 5m 53s	remaining: 55.1s
# 623:	learn: 0.0652064	total: 5m 54s	remaining: 54.6s
# 624:	learn: 0.0651998	total: 5m 55s	remaining: 54s
# 625:	learn: 0.0651985	total: 5m 56s	remaining: 53.5s
# 626:	learn: 0.0651953	total: 5m 56s	remaining: 52.9s
# 627:	learn: 0.0651935	total: 5m 57s	remaining: 52.4s
# 628:	learn: 0.0651875	total: 5m 58s	remaining: 51.9s
# 629:	learn: 0.0651801	total: 5m 59s	remaining: 51.4s
# 630:	learn: 0.0651732	total: 6m	remaining: 50.9s
# 631:	learn: 0.0651716	total: 6m 1s	remaining: 50.3s
# 632:	learn: 0.0651631	total: 6m 2s	remaining: 49.9s
# 633:	learn: 0.0651605	total: 6m 3s	remaining: 49.3s
# 634:	learn: 0.0651596	total: 6m 4s	remaining: 48.8s
# 635:	learn: 0.0651570	total: 6m 5s	remaining: 48.2s
# 636:	learn: 0.0651537	total: 6m 6s	remaining: 47.7s
# 637:	learn: 0.0651466	total: 6m 6s	remaining: 47.2s
# 638:	learn: 0.0651434	total: 6m 7s	remaining: 46.6s
# 639:	learn: 0.0651387	total: 6m 8s	remaining: 46s
# 684:	learn: 0.0649560	total: 6m 49s	remaining: 20.9s
# 685:	learn: 0.0649505	total: 6m 50s	remaining: 20.3s
# 686:	learn: 0.0649473	total: 6m 51s	remaining: 19.7s
# 687:	learn: 0.0649439	total: 6m 51s	remaining: 19.2s
# 688:	learn: 0.0649418	total: 6m 52s	remaining: 18.6s
# 689:	learn: 0.0649410	total: 6m 53s	remaining: 18s
# 690:	learn: 0.0649398	total: 6m 54s	remaining: 17.4s
# 691:	learn: 0.0649348	total: 6m 55s	remaining: 16.8s
# 692:	learn: 0.0649331	total: 6m 56s	remaining: 16.2s
# 693:	learn: 0.0649315	total: 6m 56s	remaining: 15.6s
# 694:	learn: 0.0649273	total: 6m 57s	remaining: 15s
# 695:	learn: 0.0649255	total: 6m 58s	remaining: 14.4s
# 696:	learn: 0.0649229	total: 6m 58s	remaining: 13.8s
# 697:	learn: 0.0649205	total: 6m 59s	remaining: 13.2s
# 698:	learn: 0.0649142	total: 7m	remaining: 12.6s
# 699:	learn: 0.0649129	total: 7m	remaining: 12s
# 700:	learn: 0.0649087	total: 7m 1s	remaining: 11.4s
# 701:	learn: 0.0649047	total: 7m 2s	remaining: 10.8s
# 702:	learn: 0.0649037	total: 7m 3s	remaining: 10.2s
# 703:	learn: 0.0649019	total: 7m 4s	remaining: 9.64s
# 704:	learn: 0.0648991	total: 7m 5s	remaining: 9.05s
# 705:	learn: 0.0648974	total: 7m 6s	remaining: 8.45s
# 706:	learn: 0.0648873	total: 7m 7s	remaining: 7.85s
# 707:	learn: 0.0648865	total: 7m 7s	remaining: 7.25s
# 708:	learn: 0.0648848	total: 7m 8s	remaining: 6.65s
# 709:	learn: 0.0648816	total: 7m 9s	remaining: 6.04s
# 710:	learn: 0.0648806	total: 7m 10s	remaining: 5.44s
# 711:	learn: 0.0648787	total: 7m 10s	remaining: 4.84s
# 712:	learn: 0.0648773	total: 7m 11s	remaining: 4.24s
# 713:	learn: 0.0648740	total: 7m 12s	remaining: 3.63s
# 714:	learn: 0.0648721	total: 7m 13s	remaining: 3.03s
# 715:	learn: 0.0648670	total: 7m 14s	remaining: 2.42s
# 716:	learn: 0.0648652	total: 7m 15s	remaining: 1.82s
# 717:	learn: 0.0648535	total: 7m 16s	remaining: 1.22s
# 718:	learn: 0.0648499	total: 7m 17s	remaining: 608ms
# 719:	learn: 0.0648448	total: 7m 18s	remaining: 0us

# %%
submission = pd.DataFrame({
    'ParcelId': test_df['ParcelId'],
})
test_dates = {
    '201611': pd.Timestamp('2016-10-31')
}
for label, test_date in test_dates.items():
    print("Predicting for: %s ... " % (label))
    submission[label] = y_pred
    
submission.to_csv(data_path + 'Model_3_CatBoost.csv', float_format='%.6f',index=False)
# Out:
# Predicting for: 201611 ...

# %%
predictions_model_3 = pd.read_csv(data_path + 'Model_3_CatBoost.csv')
predictions_model_3.head()
# Out:
#    ParcelId    201611
# 0  10754147  0.030659
# 1  10759547 -0.003619
# 2  10843547  0.075790
# 3  10859147  0.105809
# 4  10879947  0.020252
