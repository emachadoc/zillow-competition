# %% [markdown]
# ## CAT BOOST REGRESSOR

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
color = sns.color_palette()
import zipfile
import re
from scipy import stats
from catboost import CatBoostRegressor
from tqdm import tqdm
import gc
import datetime as dt

# %% [markdown]
# <font color = blue> Once we have imported the necessary libraries, we are going to define our data path and then, load the data: </font>

# %%
data_path = './data/'

# %%
print('Loading Properties ...')
properties2016 = pd.read_csv(data_path + 'properties_2016.csv', low_memory = False)
properties2017 = pd.read_csv(data_path + 'properties_2017.csv', low_memory = False)
# Out:
# Loading Properties ...

# %%
properties2016.head()
# Out:
#    parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0  10754147                    NaN                       NaN           NaN
# 1  10759547                    NaN                       NaN           NaN
# 2  10843547                    NaN                       NaN           NaN
# 3  10859147                    NaN                       NaN           NaN
# 4  10879947                    NaN                       NaN           NaN
#
#    bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  \
# 0          0.0         0.0                  NaN                    NaN
# 1          0.0         0.0                  NaN                    NaN
# 2          0.0         0.0                  NaN                    NaN
# 3          0.0         0.0                  3.0                    7.0
# 4          0.0         0.0                  4.0                    NaN
#
#    calculatedbathnbr  decktypeid  ...  numberofstories  fireplaceflag  \
# 0                NaN         NaN  ...              NaN            NaN
# 1                NaN         NaN  ...              NaN            NaN
# 2                NaN         NaN  ...              NaN            NaN
# 3                NaN         NaN  ...              1.0            NaN
# 4                NaN         NaN  ...              NaN            NaN
#
#    structuretaxvaluedollarcnt  taxvaluedollarcnt  assessmentyear  \
# 0                         NaN                9.0          2015.0
# 1                         NaN            27516.0          2015.0
# 2                    650756.0          1413387.0          2015.0
# 3                    571346.0          1156834.0          2015.0
# 4                    193796.0           433491.0          2015.0
#
#    landtaxvaluedollarcnt  taxamount  taxdelinquencyflag  taxdelinquencyyear  \
# 0                    9.0        NaN                 NaN                 NaN
# 1                27516.0        NaN                 NaN                 NaN
# 2               762631.0   20800.37                 NaN                 NaN
# 3               585488.0   14557.57                 NaN                 NaN
# 4               239695.0    5725.17                 NaN                 NaN
#
#    censustractandblock
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
# [5 rows x 58 columns]

# %%
properties2016.shape
# Out:
# (2985217, 58)

# %%
properties2017.head()
# Out:
#    parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0  10754147                    NaN                       NaN           NaN
# 1  10759547                    NaN                       NaN           NaN
# 2  10843547                    NaN                       NaN           NaN
# 3  10859147                    NaN                       NaN           NaN
# 4  10879947                    NaN                       NaN           NaN
#
#    bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  \
# 0          0.0         0.0                  NaN                    NaN
# 1          0.0         0.0                  NaN                    NaN
# 2          0.0         0.0                  5.0                    NaN
# 3          0.0         0.0                  3.0                    6.0
# 4          0.0         0.0                  4.0                    NaN
#
#    calculatedbathnbr  decktypeid  ...  numberofstories  fireplaceflag  \
# 0                NaN         NaN  ...              NaN            NaN
# 1                NaN         NaN  ...              NaN            NaN
# 2                NaN         NaN  ...              1.0            NaN
# 3                NaN         NaN  ...              1.0            NaN
# 4                NaN         NaN  ...              1.0            NaN
#
#    structuretaxvaluedollarcnt  taxvaluedollarcnt  assessmentyear  \
# 0                         NaN                9.0          2016.0
# 1                         NaN            27516.0          2015.0
# 2                    660680.0          1434941.0          2016.0
# 3                    580059.0          1174475.0          2016.0
# 4                    196751.0           440101.0          2016.0
#
#    landtaxvaluedollarcnt  taxamount  taxdelinquencyflag  taxdelinquencyyear  \
# 0                    9.0        NaN                 NaN                 NaN
# 1                27516.0        NaN                 NaN                 NaN
# 2               774261.0   20800.37                 NaN                 NaN
# 3               594416.0   14557.57                 NaN                 NaN
# 4               243350.0    5725.17                 NaN                 NaN
#
#    censustractandblock
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
# [5 rows x 58 columns]

# %%
properties2017.shape
# Out:
# (2985217, 58)

# %% [markdown]
# <font color = blue> We are going to specify the parameter 'parse_dates' to make the column 'transactiondate' in train files date formatted: </font>

# %%
print('Loading Train ...')
train2016 = pd.read_csv(data_path + 'train_2016_v2.csv', parse_dates=['transactiondate'], low_memory=False)
train2017 = pd.read_csv(data_path + 'train_2017.csv', parse_dates=['transactiondate'], low_memory=False)
# Out:
# Loading Train ...

# %%
train2016.shape
# Out:
# (90275, 3)

# %%
train2017.shape
# Out:
# (77613, 3)

# %%
train2016.head()
# Out:
#    parcelid  logerror transactiondate
# 0  11016594    0.0276      2016-01-01
# 1  14366692   -0.1684      2016-01-01
# 2  12098116   -0.0040      2016-01-01
# 3  12643413    0.0218      2016-01-02
# 4  14432541   -0.0050      2016-01-02

# %% [markdown]
# <font color = blue> Now we are going to parse dates to get one column for year, one for month, one for day and one for quarter: </font>

# %%
def add_date_features(df):
    df["transaction_year"] = df["transactiondate"].dt.year
    df["transaction_month"] = (df["transactiondate"].dt.year - 2016)*12 + df["transactiondate"].dt.month
    df["transaction_day"] = df["transactiondate"].dt.day
    df["transaction_quarter"] = (df["transactiondate"].dt.year - 2016)*4 + df["transactiondate"].dt.quarter
    df.drop(["transactiondate"], inplace=True, axis=1)
    return df

# %%
train2016 = add_date_features(train2016)
train2017 = add_date_features(train2017)

# %%
train2016.head()
# Out:
#    parcelid  logerror  transaction_year  transaction_month  transaction_day  \
# 0  11016594    0.0276              2016                  1                1
# 1  14366692   -0.1684              2016                  1                1
# 2  12098116   -0.0040              2016                  1                1
# 3  12643413    0.0218              2016                  1                2
# 4  14432541   -0.0050              2016                  1                2
#
#    transaction_quarter
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    1

# %%
print('Loading Sample ...')
sample_submission = pd.read_csv(data_path + 'sample_submission.csv', low_memory = False)
# Out:
# Loading Sample ...

# %% [markdown]
# <font color = blue> Our sample submission will be a file with the parcel id for each property and six prediction columns for different dates (last 2016 quarter and last 2017 quarter): </font>

# %%
sample_submission.head()
# Out:
#    ParcelId  201610  201611  201612  201710  201711  201712
# 0  10754147       0       0       0       0       0       0
# 1  10759547       0       0       0       0       0       0
# 2  10843547       0       0       0       0       0       0
# 3  10859147       0       0       0       0       0       0
# 4  10879947       0       0       0       0       0       0

# %% [markdown]
# <font color = blue> As we are going to apply the first model, cat boost, to the column for 201711 predictions, we remove the other columns: </font>

# %%
sample_submission_model_4 = sample_submission.drop(columns = ['201610', '201611', '201612', '201710', '201712'])
sample_submission_model_4.head()
# Out:
#    ParcelId  201711
# 0  10754147       0
# 1  10759547       0
# 2  10843547       0
# 3  10859147       0
# 4  10879947       0

# %% [markdown]
# <font color = blue> We will merge properties and train files to get all data grouped: </font>

# %%
print('Merging Train with Properties ...')
train2016 = pd.merge(train2016, properties2016, how = 'left', on = 'parcelid')
train2017 = pd.merge(train2017, properties2017, how = 'left', on = 'parcelid')
# Out:
# Merging Train with Properties ...

# %%
train2016.head()
# Out:
#    parcelid  logerror  transaction_year  transaction_month  transaction_day  \
# 0  11016594    0.0276              2016                  1                1
# 1  14366692   -0.1684              2016                  1                1
# 2  12098116   -0.0040              2016                  1                1
# 3  12643413    0.0218              2016                  1                2
# 4  14432541   -0.0050              2016                  1                2
#
#    transaction_quarter  airconditioningtypeid  architecturalstyletypeid  \
# 0                    1                    1.0                       NaN
# 1                    1                    NaN                       NaN
# 2                    1                    1.0                       NaN
# 3                    1                    1.0                       NaN
# 4                    1                    NaN                       NaN
#
#    basementsqft  bathroomcnt  ...  numberofstories  fireplaceflag  \
# 0           NaN          2.0  ...              NaN            NaN
# 1           NaN          3.5  ...              NaN            NaN
# 2           NaN          3.0  ...              NaN            NaN
# 3           NaN          2.0  ...              NaN            NaN
# 4           NaN          2.5  ...              2.0            NaN
#
#    structuretaxvaluedollarcnt  taxvaluedollarcnt  assessmentyear  \
# 0                    122754.0           360170.0          2015.0
# 1                    346458.0           585529.0          2015.0
# 2                     61994.0           119906.0          2015.0
# 3                    171518.0           244880.0          2015.0
# 4                    169574.0           434551.0          2015.0
#
#    landtaxvaluedollarcnt  taxamount  taxdelinquencyflag  taxdelinquencyyear  \
# 0               237416.0    6735.88                 NaN                 NaN
# 1               239071.0   10153.02                 NaN                 NaN
# 2                57912.0   11484.48                 NaN                 NaN
# 3                73362.0    3048.74                 NaN                 NaN
# 4               264977.0    5488.96                 NaN                 NaN
#
#    censustractandblock
# 0         6.037107e+13
# 1                  NaN
# 2         6.037464e+13
# 3         6.037296e+13
# 4         6.059042e+13
#
# [5 rows x 63 columns]

# %%
train2016.shape
# Out:
# (90275, 63)

# %%
train2017.head()
# Out:
#    parcelid  logerror  transaction_year  transaction_month  transaction_day  \
# 0  14297519  0.025595              2017                 13                1
# 1  17052889  0.055619              2017                 13                1
# 2  14186244  0.005383              2017                 13                1
# 3  12177905 -0.103410              2017                 13                1
# 4  10887214  0.006940              2017                 13                1
#
#    transaction_quarter  airconditioningtypeid  architecturalstyletypeid  \
# 0                    5                    NaN                       NaN
# 1                    5                    NaN                       NaN
# 2                    5                    NaN                       NaN
# 3                    5                    NaN                       NaN
# 4                    5                    1.0                       NaN
#
#    basementsqft  bathroomcnt  ...  numberofstories  fireplaceflag  \
# 0           NaN          3.5  ...              NaN            NaN
# 1           NaN          1.0  ...              1.0            NaN
# 2           NaN          2.0  ...              1.0            NaN
# 3           NaN          3.0  ...              NaN            NaN
# 4           NaN          3.0  ...              NaN            NaN
#
#    structuretaxvaluedollarcnt  taxvaluedollarcnt  assessmentyear  \
# 0                    485713.0          1023282.0          2016.0
# 1                     88000.0           464000.0          2016.0
# 2                     85289.0           564778.0          2016.0
# 3                    108918.0           145143.0          2016.0
# 4                     73681.0           119407.0          2016.0
#
#    landtaxvaluedollarcnt  taxamount  taxdelinquencyflag  taxdelinquencyyear  \
# 0               537569.0   11013.72                 NaN                 NaN
# 1               376000.0    5672.48                 NaN                 NaN
# 2               479489.0    6488.30                 NaN                 NaN
# 3                36225.0    1777.51                 NaN                 NaN
# 4                45726.0    1533.89                 NaN                 NaN
#
#    censustractandblock
# 0         6.059063e+13
# 1         6.111001e+13
# 2         6.059022e+13
# 3         6.037300e+13
# 4         6.037124e+13
#
# [5 rows x 63 columns]

# %%
train2017.shape
# Out:
# (77613, 63)

# %% [markdown]
# <font color = blue> Now we will generate our training and test files to run the model, the training file will be all properties and train from 2016 and 2017, while for the test, we will merge the sample submission with the unique properties file: </font>

# %%
print('Concat Train 2016 & 2017 ...')
train_df = pd.concat([train2016, train2017], axis = 0)
test_df = pd.merge(sample_submission_model_4[['ParcelId']], properties2016.rename(columns = {'parcelid': 'ParcelId'}), how = 'left', on = 'ParcelId')
# Out:
# Concat Train 2016 & 2017 ...

# %%
train_df.head()
# Out:
#    parcelid  logerror  transaction_year  transaction_month  transaction_day  \
# 0  11016594    0.0276              2016                  1                1
# 1  14366692   -0.1684              2016                  1                1
# 2  12098116   -0.0040              2016                  1                1
# 3  12643413    0.0218              2016                  1                2
# 4  14432541   -0.0050              2016                  1                2
#
#    transaction_quarter  airconditioningtypeid  architecturalstyletypeid  \
# 0                    1                    1.0                       NaN
# 1                    1                    NaN                       NaN
# 2                    1                    1.0                       NaN
# 3                    1                    1.0                       NaN
# 4                    1                    NaN                       NaN
#
#    basementsqft  bathroomcnt  ...  numberofstories  fireplaceflag  \
# 0           NaN          2.0  ...              NaN            NaN
# 1           NaN          3.5  ...              NaN            NaN
# 2           NaN          3.0  ...              NaN            NaN
# 3           NaN          2.0  ...              NaN            NaN
# 4           NaN          2.5  ...              2.0            NaN
#
#    structuretaxvaluedollarcnt  taxvaluedollarcnt  assessmentyear  \
# 0                    122754.0           360170.0          2015.0
# 1                    346458.0           585529.0          2015.0
# 2                     61994.0           119906.0          2015.0
# 3                    171518.0           244880.0          2015.0
# 4                    169574.0           434551.0          2015.0
#
#    landtaxvaluedollarcnt  taxamount  taxdelinquencyflag  taxdelinquencyyear  \
# 0               237416.0    6735.88                 NaN                 NaN
# 1               239071.0   10153.02                 NaN                 NaN
# 2                57912.0   11484.48                 NaN                 NaN
# 3                73362.0    3048.74                 NaN                 NaN
# 4               264977.0    5488.96                 NaN                 NaN
#
#    censustractandblock
# 0         6.037107e+13
# 1                  NaN
# 2         6.037464e+13
# 3         6.037296e+13
# 4         6.059042e+13
#
# [5 rows x 63 columns]

# %%
train_df.shape
# Out:
# (167888, 63)

# %%
test_df.head()
# Out:
#    ParcelId  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0  10754147                    NaN                       NaN           NaN
# 1  10759547                    NaN                       NaN           NaN
# 2  10843547                    NaN                       NaN           NaN
# 3  10859147                    NaN                       NaN           NaN
# 4  10879947                    NaN                       NaN           NaN
#
#    bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  \
# 0          0.0         0.0                  NaN                    NaN
# 1          0.0         0.0                  NaN                    NaN
# 2          0.0         0.0                  NaN                    NaN
# 3          0.0         0.0                  3.0                    7.0
# 4          0.0         0.0                  4.0                    NaN
#
#    calculatedbathnbr  decktypeid  ...  numberofstories  fireplaceflag  \
# 0                NaN         NaN  ...              NaN            NaN
# 1                NaN         NaN  ...              NaN            NaN
# 2                NaN         NaN  ...              NaN            NaN
# 3                NaN         NaN  ...              1.0            NaN
# 4                NaN         NaN  ...              NaN            NaN
#
#    structuretaxvaluedollarcnt  taxvaluedollarcnt  assessmentyear  \
# 0                         NaN                9.0          2015.0
# 1                         NaN            27516.0          2015.0
# 2                    650756.0          1413387.0          2015.0
# 3                    571346.0          1156834.0          2015.0
# 4                    193796.0           433491.0          2015.0
#
#    landtaxvaluedollarcnt  taxamount  taxdelinquencyflag  taxdelinquencyyear  \
# 0                    9.0        NaN                 NaN                 NaN
# 1                27516.0        NaN                 NaN                 NaN
# 2               762631.0   20800.37                 NaN                 NaN
# 3               585488.0   14557.57                 NaN                 NaN
# 4               239695.0    5725.17                 NaN                 NaN
#
#    censustractandblock
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
# [5 rows x 58 columns]

# %%
test_df.shape
# Out:
# (2985217, 58)

# %% [markdown]
# <font color = blue> To optimize memory management, we are using garbage collections algorithms (GC), which solve reference cycles (when one or more objects are referencing each other) that reference counting cannot detect: </font>

# %%
del properties2016, properties2017, train2016, train2017
gc.collect();

# %% [markdown]
# <font color = blue> Let's do some feature engineering. We have to deal with missing values, where we will establish a threshold of 98% missing values to remove those fields, and also with features with one unique value and others that we do not want to use in our training: </font>

# %%
print('Missing data fields to remove ...')
missing_perc_thresh = 0.98
exclude_missing = []
num_rows = train_df.shape[0]
for c in train_df.columns:
    num_missing = train_df[c].isnull().sum()
    if num_missing == 0:
        continue
    missing_frac = num_missing / float(num_rows)
    if missing_frac > missing_perc_thresh:
        exclude_missing.append(c)
print(exclude_missing)
print("We exclude: %s" % len(exclude_missing))
# Out:
# Missing data fields to remove ...
# ['architecturalstyletypeid', 'basementsqft', 'buildingclasstypeid', 'decktypeid', 'finishedsquarefeet13', 'finishedsquarefeet6', 'poolsizesum', 'pooltypeid10', 'pooltypeid2', 'storytypeid', 'typeconstructiontypeid', 'yardbuildingsqft26', 'fireplaceflag']
# We exclude: 13

# %%
print ("Remove features with one unique value ...")
exclude_unique = []
for c in train_df.columns:
    num_uniques = len(train_df[c].unique())
    if train_df[c].isnull().sum() != 0:
        num_uniques -= 1
    if num_uniques == 1:
        exclude_unique.append(c)
print(exclude_unique)
print("We exclude: %s" % len(exclude_unique))
# Out:
# Remove features with one unique value ...
# ['decktypeid', 'hashottuborspa', 'poolcnt', 'pooltypeid10', 'pooltypeid2', 'pooltypeid7', 'storytypeid', 'fireplaceflag', 'taxdelinquencyflag']
# We exclude: 9

# %%
del num_rows, missing_perc_thresh
gc.collect();

# %%
print ("Define training features ...")
exclude_other = ['parcelid', 'logerror', 'propertyzoningdesc']
train_features = []
for c in train_df.columns:
    if c not in exclude_missing \
       and c not in exclude_other:
        train_features.append(c)
print(train_features)
print("We use these for training: %s" % len(train_features))
# Out:
# Define training features ...
# ['transaction_year', 'transaction_month', 'transaction_day', 'transaction_quarter', 'airconditioningtypeid', 'bathroomcnt', 'bedroomcnt', 'buildingqualitytypeid', 'calculatedbathnbr', 'finishedfloor1squarefeet', 'calculatedfinishedsquarefeet', 'finishedsquarefeet12', 'finishedsquarefeet15', 'finishedsquarefeet50', 'fips', 'fireplacecnt', 'fullbathcnt', 'garagecarcnt', 'garagetotalsqft', 'hashottuborspa', 'heatingorsystemtypeid', 'latitude', 'longitude', 'lotsizesquarefeet', 'poolcnt', 'pooltypeid7', 'propertycountylandusecode', 'propertylandusetypeid', 'rawcensustractandblock', 'regionidcity', 'regionidcounty', 'regionidneighborhood', 'regionidzip', 'roomcnt', 'threequarterbathnbr', 'unitcnt', 'yardbuildingsqft17', 'yearbuilt', 'numberofstories', 'structuretaxvaluedollarcnt', 'taxvaluedollarcnt', 'assessmentyear', 'landtaxvaluedollarcnt', 'taxamount', 'taxdelinquencyflag', 'taxdelinquencyyear', 'censustractandblock']
# We use these for training: 47

# %% [markdown]
# <font color = blue> Now we have to deal with categorical features: </font>

# %%
print ("Define categorical features ...")
cat_feature_inds = []
cat_unique_thresh = 100
for i, c in enumerate(train_features):
    num_uniques = len(train_df[c].unique())
    if num_uniques < cat_unique_thresh \
       and not 'sqft' in c \
       and not 'cnt' in c \
       and not 'nbr' in c \
       and not 'number' in c:
        cat_feature_inds.append(i)
print("Cat features are: %s" % [train_features[ind] for ind in cat_feature_inds])
# Out:
# Define categorical features ...
# Cat features are: ['transaction_year', 'transaction_month', 'transaction_day', 'transaction_quarter', 'airconditioningtypeid', 'buildingqualitytypeid', 'fips', 'hashottuborspa', 'heatingorsystemtypeid', 'pooltypeid7', 'propertycountylandusecode', 'propertylandusetypeid', 'regionidcounty', 'assessmentyear', 'taxdelinquencyflag', 'taxdelinquencyyear']

# %% [markdown]
# <font color = blue> As we are going to use a tree based model, we will replace NaN values by '-999' so they do not interfere with proper data: </font>

# %%
print ("Replacing NaN values by -999 ...")
train_df.fillna(-999, inplace=True)
test_df.fillna(-999, inplace=True)
# Out:
# Replacing NaN values by -999 ...

# %%
print ("Training model 4: Cat boost ...")
X_train = train_df[train_features]
y_train = train_df.logerror
print(X_train.shape, y_train.shape)

test_df['transactiondate'] = pd.Timestamp('2016-12-01') 
test_df = add_date_features(test_df)
X_test = test_df[train_features]
print(X_test.shape)
# Out:
# Training model 4: Cat boost ...
# (167888, 47) (167888,)
# (2985217, 47)

# %%
y_pred = 0.0
model = CatBoostRegressor(
    iterations = 720, learning_rate = 0.03,
    depth = 8, l2_leaf_reg = 5,
    loss_function = 'MAE',
    eval_metric = 'MAE',
    random_seed = i)
model.fit(
    X_train, y_train,
    cat_features = cat_feature_inds)
y_pred += model.predict(X_test)
# Out:
# 0:	learn: 0.0688926	total: 828ms	remaining: 9m 55s
# 1:	learn: 0.0687281	total: 1.64s	remaining: 9m 47s
# 2:	learn: 0.0685900	total: 2.38s	remaining: 9m 29s
# 3:	learn: 0.0685118	total: 3.04s	remaining: 9m 4s
# 4:	learn: 0.0684522	total: 3.88s	remaining: 9m 15s
# 5:	learn: 0.0683974	total: 4.64s	remaining: 9m 12s
# 6:	learn: 0.0683481	total: 5.28s	remaining: 8m 57s
# 7:	learn: 0.0683024	total: 6.02s	remaining: 8m 56s
# 8:	learn: 0.0682738	total: 6.7s	remaining: 8m 49s
# 9:	learn: 0.0682541	total: 7.39s	remaining: 8m 44s
# 10:	learn: 0.0682011	total: 8.21s	remaining: 8m 49s
# 11:	learn: 0.0681781	total: 9.77s	remaining: 9m 36s
# 12:	learn: 0.0681424	total: 10.7s	remaining: 9m 42s
# 459:	learn: 0.0657173	total: 4m 57s	remaining: 2m 48s
# 460:	learn: 0.0657116	total: 4m 57s	remaining: 2m 47s
# 461:	learn: 0.0657014	total: 4m 58s	remaining: 2m 46s
# 462:	learn: 0.0656873	total: 4m 58s	remaining: 2m 45s
# 463:	learn: 0.0656758	total: 4m 59s	remaining: 2m 45s
# 464:	learn: 0.0656717	total: 4m 59s	remaining: 2m 44s
# 465:	learn: 0.0656678	total: 5m	remaining: 2m 43s
# 466:	learn: 0.0656574	total: 5m	remaining: 2m 42s
# 467:	learn: 0.0656522	total: 5m	remaining: 2m 42s
# 468:	learn: 0.0656449	total: 5m 1s	remaining: 2m 41s
# 469:	learn: 0.0656434	total: 5m 2s	remaining: 2m 40s
# 470:	learn: 0.0656389	total: 5m 2s	remaining: 2m 40s
# 471:	learn: 0.0656306	total: 5m 3s	remaining: 2m 39s
# 472:	learn: 0.0656285	total: 5m 4s	remaining: 2m 38s
# 473:	learn: 0.0656255	total: 5m 4s	remaining: 2m 38s
# 474:	learn: 0.0656226	total: 5m 5s	remaining: 2m 37s
# 475:	learn: 0.0656136	total: 5m 5s	remaining: 2m 36s
# 476:	learn: 0.0656111	total: 5m 5s	remaining: 2m 35s
# 477:	learn: 0.0656056	total: 5m 6s	remaining: 2m 35s
# 478:	learn: 0.0656009	total: 5m 6s	remaining: 2m 34s
# 479:	learn: 0.0655899	total: 5m 7s	remaining: 2m 33s
# 480:	learn: 0.0655852	total: 5m 7s	remaining: 2m 32s
# 481:	learn: 0.0655775	total: 5m 8s	remaining: 2m 32s
# 482:	learn: 0.0655707	total: 5m 8s	remaining: 2m 31s
# 483:	learn: 0.0655589	total: 5m 8s	remaining: 2m 30s
# 484:	learn: 0.0655524	total: 5m 9s	remaining: 2m 29s
# 485:	learn: 0.0655488	total: 5m 9s	remaining: 2m 29s
# 486:	learn: 0.0655399	total: 5m 10s	remaining: 2m 28s
# 487:	learn: 0.0655350	total: 5m 10s	remaining: 2m 27s
# 488:	learn: 0.0655325	total: 5m 11s	remaining: 2m 26s
# 489:	learn: 0.0655280	total: 5m 11s	remaining: 2m 26s
# 490:	learn: 0.0655189	total: 5m 11s	remaining: 2m 25s
# 491:	learn: 0.0655080	total: 5m 12s	remaining: 2m 24s
# 492:	learn: 0.0655068	total: 5m 12s	remaining: 2m 24s
# 493:	learn: 0.0655026	total: 5m 13s	remaining: 2m 23s
# 494:	learn: 0.0655000	total: 5m 14s	remaining: 2m 22s
# 495:	learn: 0.0654986	total: 5m 15s	remaining: 2m 22s
# 496:	learn: 0.0654955	total: 5m 15s	remaining: 2m 21s
# 497:	learn: 0.0654813	total: 5m 15s	remaining: 2m 20s
# 498:	learn: 0.0654703	total: 5m 16s	remaining: 2m 20s
# 499:	learn: 0.0654647	total: 5m 16s	remaining: 2m 19s
# 500:	learn: 0.0654576	total: 5m 17s	remaining: 2m 18s
# 501:	learn: 0.0654540	total: 5m 17s	remaining: 2m 17s
# 502:	learn: 0.0654473	total: 5m 17s	remaining: 2m 17s
# 503:	learn: 0.0654332	total: 5m 18s	remaining: 2m 16s
# 504:	learn: 0.0654267	total: 5m 18s	remaining: 2m 15s
# 505:	learn: 0.0654189	total: 5m 19s	remaining: 2m 15s
# 506:	learn: 0.0654163	total: 5m 19s	remaining: 2m 14s
# 507:	learn: 0.0654077	total: 5m 20s	remaining: 2m 13s
# 508:	learn: 0.0654058	total: 5m 20s	remaining: 2m 12s
# 509:	learn: 0.0653973	total: 5m 20s	remaining: 2m 12s
# 510:	learn: 0.0653963	total: 5m 21s	remaining: 2m 11s
# 511:	learn: 0.0653864	total: 5m 21s	remaining: 2m 10s
# 512:	learn: 0.0653846	total: 5m 22s	remaining: 2m 9s
# 513:	learn: 0.0653785	total: 5m 22s	remaining: 2m 9s
# 514:	learn: 0.0653719	total: 5m 22s	remaining: 2m 8s
# 515:	learn: 0.0653596	total: 5m 23s	remaining: 2m 7s
# 516:	learn: 0.0653572	total: 5m 23s	remaining: 2m 7s
# 517:	learn: 0.0653483	total: 5m 25s	remaining: 2m 6s
# 518:	learn: 0.0653337	total: 5m 25s	remaining: 2m 6s
# 519:	learn: 0.0653306	total: 5m 26s	remaining: 2m 5s
# 520:	learn: 0.0653219	total: 5m 26s	remaining: 2m 4s
# 521:	learn: 0.0653175	total: 5m 26s	remaining: 2m 3s
# 522:	learn: 0.0653126	total: 5m 27s	remaining: 2m 3s
# 523:	learn: 0.0653042	total: 5m 27s	remaining: 2m 2s
# 524:	learn: 0.0652922	total: 5m 28s	remaining: 2m 1s
# 525:	learn: 0.0652893	total: 5m 28s	remaining: 2m 1s
# 526:	learn: 0.0652848	total: 5m 28s	remaining: 2m
# 527:	learn: 0.0652734	total: 5m 29s	remaining: 1m 59s
# 528:	learn: 0.0652646	total: 5m 29s	remaining: 1m 59s
# 529:	learn: 0.0652631	total: 5m 30s	remaining: 1m 58s
# 530:	learn: 0.0652542	total: 5m 30s	remaining: 1m 57s
# 531:	learn: 0.0652438	total: 5m 30s	remaining: 1m 56s
# 532:	learn: 0.0652341	total: 5m 31s	remaining: 1m 56s
# 533:	learn: 0.0652284	total: 5m 31s	remaining: 1m 55s
# 534:	learn: 0.0652199	total: 5m 32s	remaining: 1m 54s
# 535:	learn: 0.0652132	total: 5m 32s	remaining: 1m 54s
# 536:	learn: 0.0652070	total: 5m 33s	remaining: 1m 53s
# 537:	learn: 0.0652046	total: 5m 33s	remaining: 1m 52s
# 538:	learn: 0.0651974	total: 5m 34s	remaining: 1m 52s
# 539:	learn: 0.0651938	total: 5m 34s	remaining: 1m 51s
# 540:	learn: 0.0651850	total: 5m 35s	remaining: 1m 51s
# 541:	learn: 0.0651812	total: 5m 36s	remaining: 1m 50s
# 542:	learn: 0.0651794	total: 5m 36s	remaining: 1m 49s
# 543:	learn: 0.0651737	total: 5m 36s	remaining: 1m 49s
# 544:	learn: 0.0651686	total: 5m 37s	remaining: 1m 48s
# 545:	learn: 0.0651584	total: 5m 37s	remaining: 1m 47s
# 546:	learn: 0.0651484	total: 5m 38s	remaining: 1m 46s
# 547:	learn: 0.0651443	total: 5m 38s	remaining: 1m 46s
# 548:	learn: 0.0651419	total: 5m 39s	remaining: 1m 45s
# 549:	learn: 0.0651381	total: 5m 39s	remaining: 1m 44s
# 550:	learn: 0.0651345	total: 5m 39s	remaining: 1m 44s
# 551:	learn: 0.0651297	total: 5m 40s	remaining: 1m 43s
# 552:	learn: 0.0651257	total: 5m 40s	remaining: 1m 42s
# 553:	learn: 0.0651142	total: 5m 41s	remaining: 1m 42s
# 554:	learn: 0.0651103	total: 5m 41s	remaining: 1m 41s
# 555:	learn: 0.0651042	total: 5m 42s	remaining: 1m 40s
# 556:	learn: 0.0650968	total: 5m 42s	remaining: 1m 40s
# 557:	learn: 0.0650947	total: 5m 43s	remaining: 1m 39s
# 558:	learn: 0.0650872	total: 5m 43s	remaining: 1m 39s
# 559:	learn: 0.0650841	total: 5m 44s	remaining: 1m 38s
# 560:	learn: 0.0650799	total: 5m 45s	remaining: 1m 37s
# 561:	learn: 0.0650719	total: 5m 46s	remaining: 1m 37s
# 562:	learn: 0.0650639	total: 5m 46s	remaining: 1m 36s
# 563:	learn: 0.0650514	total: 5m 47s	remaining: 1m 36s
# 564:	learn: 0.0650435	total: 5m 47s	remaining: 1m 35s
# 565:	learn: 0.0650392	total: 5m 48s	remaining: 1m 34s
# 566:	learn: 0.0650368	total: 5m 48s	remaining: 1m 34s
# 567:	learn: 0.0650326	total: 5m 48s	remaining: 1m 33s
# 568:	learn: 0.0650290	total: 5m 49s	remaining: 1m 32s
# 569:	learn: 0.0650241	total: 5m 49s	remaining: 1m 32s
# 570:	learn: 0.0650200	total: 5m 50s	remaining: 1m 31s
# 571:	learn: 0.0650168	total: 5m 50s	remaining: 1m 30s
# 572:	learn: 0.0650086	total: 5m 51s	remaining: 1m 30s
# 573:	learn: 0.0650071	total: 5m 51s	remaining: 1m 29s
# 574:	learn: 0.0650034	total: 5m 52s	remaining: 1m 28s
# 575:	learn: 0.0649997	total: 5m 52s	remaining: 1m 28s
# 576:	learn: 0.0649983	total: 5m 52s	remaining: 1m 27s
# 577:	learn: 0.0649972	total: 5m 53s	remaining: 1m 26s
# 578:	learn: 0.0649921	total: 5m 53s	remaining: 1m 26s
# 579:	learn: 0.0649912	total: 5m 54s	remaining: 1m 25s
# 580:	learn: 0.0649861	total: 5m 54s	remaining: 1m 24s
# 581:	learn: 0.0649831	total: 5m 55s	remaining: 1m 24s
# 582:	learn: 0.0649756	total: 5m 55s	remaining: 1m 23s
# 583:	learn: 0.0649673	total: 5m 56s	remaining: 1m 23s
# 584:	learn: 0.0649661	total: 5m 57s	remaining: 1m 22s
# 585:	learn: 0.0649636	total: 5m 57s	remaining: 1m 21s
# 586:	learn: 0.0649587	total: 5m 58s	remaining: 1m 21s
# 587:	learn: 0.0649509	total: 5m 58s	remaining: 1m 20s
# 588:	learn: 0.0649479	total: 5m 59s	remaining: 1m 19s
# 589:	learn: 0.0649456	total: 5m 59s	remaining: 1m 19s
# 590:	learn: 0.0649395	total: 6m	remaining: 1m 18s
# 591:	learn: 0.0649287	total: 6m	remaining: 1m 17s
# 683:	learn: 0.0645028	total: 6m 42s	remaining: 21.2s
# 684:	learn: 0.0644961	total: 6m 42s	remaining: 20.6s
# 685:	learn: 0.0644944	total: 6m 43s	remaining: 20s
# 686:	learn: 0.0644904	total: 6m 43s	remaining: 19.4s
# 687:	learn: 0.0644847	total: 6m 43s	remaining: 18.8s
# 688:	learn: 0.0644797	total: 6m 44s	remaining: 18.2s
# 689:	learn: 0.0644754	total: 6m 44s	remaining: 17.6s
# 690:	learn: 0.0644681	total: 6m 45s	remaining: 17s
# 691:	learn: 0.0644675	total: 6m 45s	remaining: 16.4s
# 692:	learn: 0.0644666	total: 6m 45s	remaining: 15.8s
# 693:	learn: 0.0644572	total: 6m 46s	remaining: 15.2s
# 694:	learn: 0.0644566	total: 6m 46s	remaining: 14.6s
# 695:	learn: 0.0644529	total: 6m 46s	remaining: 14s
# 696:	learn: 0.0644503	total: 6m 47s	remaining: 13.4s
# 697:	learn: 0.0644411	total: 6m 47s	remaining: 12.9s
# 698:	learn: 0.0644317	total: 6m 48s	remaining: 12.3s
# 699:	learn: 0.0644236	total: 6m 49s	remaining: 11.7s
# 700:	learn: 0.0644202	total: 6m 49s	remaining: 11.1s
# 701:	learn: 0.0644114	total: 6m 50s	remaining: 10.5s
# 702:	learn: 0.0644086	total: 6m 50s	remaining: 9.93s
# 703:	learn: 0.0644059	total: 6m 51s	remaining: 9.35s
# 704:	learn: 0.0643968	total: 6m 51s	remaining: 8.76s
# 705:	learn: 0.0643958	total: 6m 51s	remaining: 8.17s
# 706:	learn: 0.0643929	total: 6m 52s	remaining: 7.58s
# 707:	learn: 0.0643902	total: 6m 52s	remaining: 7s
# 708:	learn: 0.0643852	total: 6m 53s	remaining: 6.41s
# 709:	learn: 0.0643792	total: 6m 53s	remaining: 5.82s
# 710:	learn: 0.0643727	total: 6m 53s	remaining: 5.24s
# 711:	learn: 0.0643669	total: 6m 54s	remaining: 4.65s
# 712:	learn: 0.0643654	total: 6m 54s	remaining: 4.07s
# 713:	learn: 0.0643628	total: 6m 54s	remaining: 3.49s
# 714:	learn: 0.0643591	total: 6m 55s	remaining: 2.9s
# 715:	learn: 0.0643562	total: 6m 55s	remaining: 2.32s
# 716:	learn: 0.0643497	total: 6m 56s	remaining: 1.74s
# 717:	learn: 0.0643466	total: 6m 56s	remaining: 1.16s
# 718:	learn: 0.0643438	total: 6m 56s	remaining: 580ms
# 719:	learn: 0.0643404	total: 6m 57s	remaining: 0us

# %%
submission = pd.DataFrame({
    'ParcelId': test_df['ParcelId'],
})
test_dates = {
    '201711': pd.Timestamp('2017-10-31')
}
for label, test_date in test_dates.items():
    print("Predicting for: %s ... " % (label))
    submission[label] = y_pred
    
submission.to_csv(data_path + 'Model_4_CatBoost.csv', float_format='%.6f',index=False)
# Out:
# Predicting for: 201711 ...

# %%
predictions_model_4 = pd.read_csv(data_path + 'Model_4_CatBoost.csv')
predictions_model_4.head()
# Out:
#    ParcelId    201711
# 0  10754147  0.033367
# 1  10759547  0.008797
# 2  10843547  0.006214
# 3  10859147  0.032230
# 4  10879947 -0.005727
