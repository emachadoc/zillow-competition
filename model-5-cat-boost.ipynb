# %% [markdown]
# ## CAT BOOST REGRESSOR

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
color = sns.color_palette()
import zipfile
import re
from scipy import stats
from catboost import CatBoostRegressor
from tqdm import tqdm
import gc
import datetime as dt

# %% [markdown]
# <font color = blue> Once we have imported the necessary libraries, we are going to define our data path and then, load the data: </font>

# %%
data_path = './data/'

# %%
print('Loading Properties ...')
properties2016 = pd.read_csv(data_path + 'properties_2016.csv', low_memory = False)
properties2017 = pd.read_csv(data_path + 'properties_2017.csv', low_memory = False)
# Out:
# Loading Properties ...

# %%
properties2016.head()
# Out:
#    parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0  10754147                    NaN                       NaN           NaN
# 1  10759547                    NaN                       NaN           NaN
# 2  10843547                    NaN                       NaN           NaN
# 3  10859147                    NaN                       NaN           NaN
# 4  10879947                    NaN                       NaN           NaN
#
#    bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  \
# 0          0.0         0.0                  NaN                    NaN
# 1          0.0         0.0                  NaN                    NaN
# 2          0.0         0.0                  NaN                    NaN
# 3          0.0         0.0                  3.0                    7.0
# 4          0.0         0.0                  4.0                    NaN
#
#    calculatedbathnbr  decktypeid  ...  numberofstories  fireplaceflag  \
# 0                NaN         NaN  ...              NaN            NaN
# 1                NaN         NaN  ...              NaN            NaN
# 2                NaN         NaN  ...              NaN            NaN
# 3                NaN         NaN  ...              1.0            NaN
# 4                NaN         NaN  ...              NaN            NaN
#
#    structuretaxvaluedollarcnt  taxvaluedollarcnt  assessmentyear  \
# 0                         NaN                9.0          2015.0
# 1                         NaN            27516.0          2015.0
# 2                    650756.0          1413387.0          2015.0
# 3                    571346.0          1156834.0          2015.0
# 4                    193796.0           433491.0          2015.0
#
#    landtaxvaluedollarcnt  taxamount  taxdelinquencyflag  taxdelinquencyyear  \
# 0                    9.0        NaN                 NaN                 NaN
# 1                27516.0        NaN                 NaN                 NaN
# 2               762631.0   20800.37                 NaN                 NaN
# 3               585488.0   14557.57                 NaN                 NaN
# 4               239695.0    5725.17                 NaN                 NaN
#
#    censustractandblock
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
# [5 rows x 58 columns]

# %%
properties2016.shape
# Out:
# (2985217, 58)

# %%
properties2017.head()
# Out:
#    parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0  10754147                    NaN                       NaN           NaN
# 1  10759547                    NaN                       NaN           NaN
# 2  10843547                    NaN                       NaN           NaN
# 3  10859147                    NaN                       NaN           NaN
# 4  10879947                    NaN                       NaN           NaN
#
#    bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  \
# 0          0.0         0.0                  NaN                    NaN
# 1          0.0         0.0                  NaN                    NaN
# 2          0.0         0.0                  5.0                    NaN
# 3          0.0         0.0                  3.0                    6.0
# 4          0.0         0.0                  4.0                    NaN
#
#    calculatedbathnbr  decktypeid  ...  numberofstories  fireplaceflag  \
# 0                NaN         NaN  ...              NaN            NaN
# 1                NaN         NaN  ...              NaN            NaN
# 2                NaN         NaN  ...              1.0            NaN
# 3                NaN         NaN  ...              1.0            NaN
# 4                NaN         NaN  ...              1.0            NaN
#
#    structuretaxvaluedollarcnt  taxvaluedollarcnt  assessmentyear  \
# 0                         NaN                9.0          2016.0
# 1                         NaN            27516.0          2015.0
# 2                    660680.0          1434941.0          2016.0
# 3                    580059.0          1174475.0          2016.0
# 4                    196751.0           440101.0          2016.0
#
#    landtaxvaluedollarcnt  taxamount  taxdelinquencyflag  taxdelinquencyyear  \
# 0                    9.0        NaN                 NaN                 NaN
# 1                27516.0        NaN                 NaN                 NaN
# 2               774261.0   20800.37                 NaN                 NaN
# 3               594416.0   14557.57                 NaN                 NaN
# 4               243350.0    5725.17                 NaN                 NaN
#
#    censustractandblock
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
# [5 rows x 58 columns]

# %%
properties2017.shape
# Out:
# (2985217, 58)

# %% [markdown]
# <font color = blue> We are going to specify the parameter 'parse_dates' to make the column 'transactiondate' in train files date formatted: </font>

# %%
print('Loading Train ...')
train2016 = pd.read_csv(data_path + 'train_2016_v2.csv', parse_dates=['transactiondate'], low_memory=False)
train2017 = pd.read_csv(data_path + 'train_2017.csv', parse_dates=['transactiondate'], low_memory=False)
# Out:
# Loading Train ...

# %%
train2016.shape
# Out:
# (90275, 3)

# %%
train2017.shape
# Out:
# (77613, 3)

# %%
train2016.head()
# Out:
#    parcelid  logerror transactiondate
# 0  11016594    0.0276      2016-01-01
# 1  14366692   -0.1684      2016-01-01
# 2  12098116   -0.0040      2016-01-01
# 3  12643413    0.0218      2016-01-02
# 4  14432541   -0.0050      2016-01-02

# %% [markdown]
# <font color = blue> Now we are going to parse dates to get one column for year, one for month, one for day and one for quarter: </font>

# %%
def add_date_features(df):
    df["transaction_year"] = df["transactiondate"].dt.year
    df["transaction_month"] = (df["transactiondate"].dt.year - 2016)*12 + df["transactiondate"].dt.month
    df["transaction_day"] = df["transactiondate"].dt.day
    df["transaction_quarter"] = (df["transactiondate"].dt.year - 2016)*4 + df["transactiondate"].dt.quarter
    df.drop(["transactiondate"], inplace=True, axis=1)
    return df

# %%
train2016 = add_date_features(train2016)
train2017 = add_date_features(train2017)

# %%
train2016.head()
# Out:
#    parcelid  logerror  transaction_year  transaction_month  transaction_day  \
# 0  11016594    0.0276              2016                  1                1
# 1  14366692   -0.1684              2016                  1                1
# 2  12098116   -0.0040              2016                  1                1
# 3  12643413    0.0218              2016                  1                2
# 4  14432541   -0.0050              2016                  1                2
#
#    transaction_quarter
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    1

# %%
print('Loading Sample ...')
sample_submission = pd.read_csv(data_path + 'sample_submission.csv', low_memory = False)
# Out:
# Loading Sample ...

# %% [markdown]
# <font color = blue> Our sample submission will be a file with the parcel id for each property and six prediction columns for different dates (last 2016 quarter and last 2017 quarter): </font>

# %%
sample_submission.head()
# Out:
#    ParcelId  201610  201611  201612  201710  201711  201712
# 0  10754147       0       0       0       0       0       0
# 1  10759547       0       0       0       0       0       0
# 2  10843547       0       0       0       0       0       0
# 3  10859147       0       0       0       0       0       0
# 4  10879947       0       0       0       0       0       0

# %% [markdown]
# <font color = blue> As we are going to apply the first model, cat boost, to the column for 201612 predictions, we remove the other columns: </font>

# %%
sample_submission_model_5 = sample_submission.drop(columns = ['201610', '201611', '201710', '201711', '201712'])
sample_submission_model_5.head()
# Out:
#    ParcelId  201612
# 0  10754147       0
# 1  10759547       0
# 2  10843547       0
# 3  10859147       0
# 4  10879947       0

# %% [markdown]
# <font color = blue> We will merge properties and train files to get all data grouped: </font>

# %%
print('Merging Train with Properties ...')
train2016 = pd.merge(train2016, properties2016, how = 'left', on = 'parcelid')
train2017 = pd.merge(train2017, properties2017, how = 'left', on = 'parcelid')
# Out:
# Merging Train with Properties ...

# %%
train2016.head()
# Out:
#    parcelid  logerror  transaction_year  transaction_month  transaction_day  \
# 0  11016594    0.0276              2016                  1                1
# 1  14366692   -0.1684              2016                  1                1
# 2  12098116   -0.0040              2016                  1                1
# 3  12643413    0.0218              2016                  1                2
# 4  14432541   -0.0050              2016                  1                2
#
#    transaction_quarter  airconditioningtypeid  architecturalstyletypeid  \
# 0                    1                    1.0                       NaN
# 1                    1                    NaN                       NaN
# 2                    1                    1.0                       NaN
# 3                    1                    1.0                       NaN
# 4                    1                    NaN                       NaN
#
#    basementsqft  bathroomcnt  ...  numberofstories  fireplaceflag  \
# 0           NaN          2.0  ...              NaN            NaN
# 1           NaN          3.5  ...              NaN            NaN
# 2           NaN          3.0  ...              NaN            NaN
# 3           NaN          2.0  ...              NaN            NaN
# 4           NaN          2.5  ...              2.0            NaN
#
#    structuretaxvaluedollarcnt  taxvaluedollarcnt  assessmentyear  \
# 0                    122754.0           360170.0          2015.0
# 1                    346458.0           585529.0          2015.0
# 2                     61994.0           119906.0          2015.0
# 3                    171518.0           244880.0          2015.0
# 4                    169574.0           434551.0          2015.0
#
#    landtaxvaluedollarcnt  taxamount  taxdelinquencyflag  taxdelinquencyyear  \
# 0               237416.0    6735.88                 NaN                 NaN
# 1               239071.0   10153.02                 NaN                 NaN
# 2                57912.0   11484.48                 NaN                 NaN
# 3                73362.0    3048.74                 NaN                 NaN
# 4               264977.0    5488.96                 NaN                 NaN
#
#    censustractandblock
# 0         6.037107e+13
# 1                  NaN
# 2         6.037464e+13
# 3         6.037296e+13
# 4         6.059042e+13
#
# [5 rows x 63 columns]

# %%
train2016.shape
# Out:
# (90275, 63)

# %%
train2017.head()
# Out:
#    parcelid  logerror  transaction_year  transaction_month  transaction_day  \
# 0  14297519  0.025595              2017                 13                1
# 1  17052889  0.055619              2017                 13                1
# 2  14186244  0.005383              2017                 13                1
# 3  12177905 -0.103410              2017                 13                1
# 4  10887214  0.006940              2017                 13                1
#
#    transaction_quarter  airconditioningtypeid  architecturalstyletypeid  \
# 0                    5                    NaN                       NaN
# 1                    5                    NaN                       NaN
# 2                    5                    NaN                       NaN
# 3                    5                    NaN                       NaN
# 4                    5                    1.0                       NaN
#
#    basementsqft  bathroomcnt  ...  numberofstories  fireplaceflag  \
# 0           NaN          3.5  ...              NaN            NaN
# 1           NaN          1.0  ...              1.0            NaN
# 2           NaN          2.0  ...              1.0            NaN
# 3           NaN          3.0  ...              NaN            NaN
# 4           NaN          3.0  ...              NaN            NaN
#
#    structuretaxvaluedollarcnt  taxvaluedollarcnt  assessmentyear  \
# 0                    485713.0          1023282.0          2016.0
# 1                     88000.0           464000.0          2016.0
# 2                     85289.0           564778.0          2016.0
# 3                    108918.0           145143.0          2016.0
# 4                     73681.0           119407.0          2016.0
#
#    landtaxvaluedollarcnt  taxamount  taxdelinquencyflag  taxdelinquencyyear  \
# 0               537569.0   11013.72                 NaN                 NaN
# 1               376000.0    5672.48                 NaN                 NaN
# 2               479489.0    6488.30                 NaN                 NaN
# 3                36225.0    1777.51                 NaN                 NaN
# 4                45726.0    1533.89                 NaN                 NaN
#
#    censustractandblock
# 0         6.059063e+13
# 1         6.111001e+13
# 2         6.059022e+13
# 3         6.037300e+13
# 4         6.037124e+13
#
# [5 rows x 63 columns]

# %%
train2017.shape
# Out:
# (77613, 63)

# %% [markdown]
# <font color = blue> As we should not use the 2016 tax values when predicting log errors against the 2016 log errors, we will omit this information for the 2016 predicitons columns: </font>

# %%
print('Tax Features 2017  ...')
train2017.iloc[:, train2017.columns.str.startswith('tax')] = np.nan
train2017.iloc[:, train2017.columns.str.endswith('taxvaluedollarcnt')] = np.nan
# Out:
# Tax Features 2017  ...

# %%
train2017.head()
# Out:
#    parcelid  logerror  transaction_year  transaction_month  transaction_day  \
# 0  14297519  0.025595              2017                 13                1
# 1  17052889  0.055619              2017                 13                1
# 2  14186244  0.005383              2017                 13                1
# 3  12177905 -0.103410              2017                 13                1
# 4  10887214  0.006940              2017                 13                1
#
#    transaction_quarter  airconditioningtypeid  architecturalstyletypeid  \
# 0                    5                    NaN                       NaN
# 1                    5                    NaN                       NaN
# 2                    5                    NaN                       NaN
# 3                    5                    NaN                       NaN
# 4                    5                    1.0                       NaN
#
#    basementsqft  bathroomcnt  ...  numberofstories  fireplaceflag  \
# 0           NaN          3.5  ...              NaN            NaN
# 1           NaN          1.0  ...              1.0            NaN
# 2           NaN          2.0  ...              1.0            NaN
# 3           NaN          3.0  ...              NaN            NaN
# 4           NaN          3.0  ...              NaN            NaN
#
#    structuretaxvaluedollarcnt  taxvaluedollarcnt  assessmentyear  \
# 0                         NaN                NaN          2016.0
# 1                         NaN                NaN          2016.0
# 2                         NaN                NaN          2016.0
# 3                         NaN                NaN          2016.0
# 4                         NaN                NaN          2016.0
#
#    landtaxvaluedollarcnt  taxamount  taxdelinquencyflag  taxdelinquencyyear  \
# 0                    NaN        NaN                 NaN                 NaN
# 1                    NaN        NaN                 NaN                 NaN
# 2                    NaN        NaN                 NaN                 NaN
# 3                    NaN        NaN                 NaN                 NaN
# 4                    NaN        NaN                 NaN                 NaN
#
#    censustractandblock
# 0         6.059063e+13
# 1         6.111001e+13
# 2         6.059022e+13
# 3         6.037300e+13
# 4         6.037124e+13
#
# [5 rows x 63 columns]

# %% [markdown]
# <font color = blue> Now we will generate our training and test files to run the model, the training file will be all properties and train from 2016 and 2017, while for the test, we will merge the sample submission with the unique properties file: </font>

# %%
print('Concat Train 2016 & 2017 ...')
train_df = pd.concat([train2016, train2017], axis = 0)
test_df = pd.merge(sample_submission_model_5[['ParcelId']], properties2016.rename(columns = {'parcelid': 'ParcelId'}), how = 'left', on = 'ParcelId')
# Out:
# Concat Train 2016 & 2017 ...

# %%
train_df.head()
# Out:
#    parcelid  logerror  transaction_year  transaction_month  transaction_day  \
# 0  11016594    0.0276              2016                  1                1
# 1  14366692   -0.1684              2016                  1                1
# 2  12098116   -0.0040              2016                  1                1
# 3  12643413    0.0218              2016                  1                2
# 4  14432541   -0.0050              2016                  1                2
#
#    transaction_quarter  airconditioningtypeid  architecturalstyletypeid  \
# 0                    1                    1.0                       NaN
# 1                    1                    NaN                       NaN
# 2                    1                    1.0                       NaN
# 3                    1                    1.0                       NaN
# 4                    1                    NaN                       NaN
#
#    basementsqft  bathroomcnt  ...  numberofstories  fireplaceflag  \
# 0           NaN          2.0  ...              NaN            NaN
# 1           NaN          3.5  ...              NaN            NaN
# 2           NaN          3.0  ...              NaN            NaN
# 3           NaN          2.0  ...              NaN            NaN
# 4           NaN          2.5  ...              2.0            NaN
#
#    structuretaxvaluedollarcnt  taxvaluedollarcnt  assessmentyear  \
# 0                    122754.0           360170.0          2015.0
# 1                    346458.0           585529.0          2015.0
# 2                     61994.0           119906.0          2015.0
# 3                    171518.0           244880.0          2015.0
# 4                    169574.0           434551.0          2015.0
#
#    landtaxvaluedollarcnt  taxamount  taxdelinquencyflag  taxdelinquencyyear  \
# 0               237416.0    6735.88                 NaN                 NaN
# 1               239071.0   10153.02                 NaN                 NaN
# 2                57912.0   11484.48                 NaN                 NaN
# 3                73362.0    3048.74                 NaN                 NaN
# 4               264977.0    5488.96                 NaN                 NaN
#
#    censustractandblock
# 0         6.037107e+13
# 1                  NaN
# 2         6.037464e+13
# 3         6.037296e+13
# 4         6.059042e+13
#
# [5 rows x 63 columns]

# %%
train_df.shape
# Out:
# (167888, 63)

# %%
test_df.head()
# Out:
#    ParcelId  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0  10754147                    NaN                       NaN           NaN
# 1  10759547                    NaN                       NaN           NaN
# 2  10843547                    NaN                       NaN           NaN
# 3  10859147                    NaN                       NaN           NaN
# 4  10879947                    NaN                       NaN           NaN
#
#    bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  \
# 0          0.0         0.0                  NaN                    NaN
# 1          0.0         0.0                  NaN                    NaN
# 2          0.0         0.0                  NaN                    NaN
# 3          0.0         0.0                  3.0                    7.0
# 4          0.0         0.0                  4.0                    NaN
#
#    calculatedbathnbr  decktypeid  ...  numberofstories  fireplaceflag  \
# 0                NaN         NaN  ...              NaN            NaN
# 1                NaN         NaN  ...              NaN            NaN
# 2                NaN         NaN  ...              NaN            NaN
# 3                NaN         NaN  ...              1.0            NaN
# 4                NaN         NaN  ...              NaN            NaN
#
#    structuretaxvaluedollarcnt  taxvaluedollarcnt  assessmentyear  \
# 0                         NaN                9.0          2015.0
# 1                         NaN            27516.0          2015.0
# 2                    650756.0          1413387.0          2015.0
# 3                    571346.0          1156834.0          2015.0
# 4                    193796.0           433491.0          2015.0
#
#    landtaxvaluedollarcnt  taxamount  taxdelinquencyflag  taxdelinquencyyear  \
# 0                    9.0        NaN                 NaN                 NaN
# 1                27516.0        NaN                 NaN                 NaN
# 2               762631.0   20800.37                 NaN                 NaN
# 3               585488.0   14557.57                 NaN                 NaN
# 4               239695.0    5725.17                 NaN                 NaN
#
#    censustractandblock
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
# [5 rows x 58 columns]

# %%
test_df.shape
# Out:
# (2985217, 58)

# %% [markdown]
# <font color = blue> To optimize memory management, we are using garbage collections algorithms (GC), which solve reference cycles (when one or more objects are referencing each other) that reference counting cannot detect: </font>

# %%
del properties2016, properties2017, train2016, train2017
gc.collect();

# %% [markdown]
# <font color = blue> Let's do some feature engineering. We have to deal with missing values, where we will establish a threshold of 98% missing values to remove those fields, and also with features with one unique value and others that we do not want to use in our training: </font>

# %%
print('Missing data fields to remove ...')
missing_perc_thresh = 0.98
exclude_missing = []
num_rows = train_df.shape[0]
for c in train_df.columns:
    num_missing = train_df[c].isnull().sum()
    if num_missing == 0:
        continue
    missing_frac = num_missing / float(num_rows)
    if missing_frac > missing_perc_thresh:
        exclude_missing.append(c)
print(exclude_missing)
print("We exclude: %s" % len(exclude_missing))
# Out:
# Missing data fields to remove ...
# ['architecturalstyletypeid', 'basementsqft', 'buildingclasstypeid', 'decktypeid', 'finishedsquarefeet13', 'finishedsquarefeet6', 'poolsizesum', 'pooltypeid10', 'pooltypeid2', 'storytypeid', 'typeconstructiontypeid', 'yardbuildingsqft26', 'fireplaceflag', 'taxdelinquencyflag', 'taxdelinquencyyear']
# We exclude: 15

# %%
print ("Remove features with one unique value ...")
exclude_unique = []
for c in train_df.columns:
    num_uniques = len(train_df[c].unique())
    if train_df[c].isnull().sum() != 0:
        num_uniques -= 1
    if num_uniques == 1:
        exclude_unique.append(c)
print(exclude_unique)
print("We exclude: %s" % len(exclude_unique))
# Out:
# Remove features with one unique value ...
# ['decktypeid', 'hashottuborspa', 'poolcnt', 'pooltypeid10', 'pooltypeid2', 'pooltypeid7', 'storytypeid', 'fireplaceflag', 'taxdelinquencyflag']
# We exclude: 9

# %%
del num_rows, missing_perc_thresh
gc.collect();

# %%
print ("Define training features ...")
exclude_other = ['parcelid', 'logerror', 'propertyzoningdesc']
train_features = []
for c in train_df.columns:
    if c not in exclude_missing \
       and c not in exclude_other:
        train_features.append(c)
print(train_features)
print("We use these for training: %s" % len(train_features))
# Out:
# Define training features ...
# ['transaction_year', 'transaction_month', 'transaction_day', 'transaction_quarter', 'airconditioningtypeid', 'bathroomcnt', 'bedroomcnt', 'buildingqualitytypeid', 'calculatedbathnbr', 'finishedfloor1squarefeet', 'calculatedfinishedsquarefeet', 'finishedsquarefeet12', 'finishedsquarefeet15', 'finishedsquarefeet50', 'fips', 'fireplacecnt', 'fullbathcnt', 'garagecarcnt', 'garagetotalsqft', 'hashottuborspa', 'heatingorsystemtypeid', 'latitude', 'longitude', 'lotsizesquarefeet', 'poolcnt', 'pooltypeid7', 'propertycountylandusecode', 'propertylandusetypeid', 'rawcensustractandblock', 'regionidcity', 'regionidcounty', 'regionidneighborhood', 'regionidzip', 'roomcnt', 'threequarterbathnbr', 'unitcnt', 'yardbuildingsqft17', 'yearbuilt', 'numberofstories', 'structuretaxvaluedollarcnt', 'taxvaluedollarcnt', 'assessmentyear', 'landtaxvaluedollarcnt', 'taxamount', 'censustractandblock']
# We use these for training: 45

# %% [markdown]
# <font color = blue> Now we have to deal with categorical features: </font>

# %%
print ("Define categorical features ...")
cat_feature_inds = []
cat_unique_thresh = 100
for i, c in enumerate(train_features):
    num_uniques = len(train_df[c].unique())
    if num_uniques < cat_unique_thresh \
       and not 'sqft' in c \
       and not 'cnt' in c \
       and not 'nbr' in c \
       and not 'number' in c:
        cat_feature_inds.append(i)
print("Cat features are: %s" % [train_features[ind] for ind in cat_feature_inds])
# Out:
# Define categorical features ...
# Cat features are: ['transaction_year', 'transaction_month', 'transaction_day', 'transaction_quarter', 'airconditioningtypeid', 'buildingqualitytypeid', 'fips', 'hashottuborspa', 'heatingorsystemtypeid', 'pooltypeid7', 'propertycountylandusecode', 'propertylandusetypeid', 'regionidcounty', 'assessmentyear']

# %% [markdown]
# <font color = blue> As we are going to use a tree based model, we will replace NaN values by '-999' so they do not interfere with proper data: </font>

# %%
print ("Replacing NaN values by -999 ...")
train_df.fillna(-999, inplace=True)
test_df.fillna(-999, inplace=True)
# Out:
# Replacing NaN values by -999 ...

# %%
print ("Training model 5: Cat boost ...")
X_train = train_df[train_features]
y_train = train_df.logerror
print(X_train.shape, y_train.shape)

test_df['transactiondate'] = pd.Timestamp('2016-12-01') 
test_df = add_date_features(test_df)
X_test = test_df[train_features]
print(X_test.shape)
# Out:
# Training model 5: Cat boost ...
# (167888, 45) (167888,)
# (2985217, 45)

# %%
y_pred = 0.0
model = CatBoostRegressor(
    iterations = 690, learning_rate = 0.01,
    depth = 7, l2_leaf_reg = 5,
    loss_function = 'MAE',
    eval_metric = 'MAE',
    random_seed = i)
model.fit(
    X_train, y_train,
    cat_features = cat_feature_inds)
y_pred += model.predict(X_test)
# Out:
# 0:	learn: 0.0690998	total: 679ms	remaining: 7m 48s
# 1:	learn: 0.0689989	total: 1.15s	remaining: 6m 34s
# 2:	learn: 0.0689224	total: 1.6s	remaining: 6m 5s
# 3:	learn: 0.0688491	total: 2.15s	remaining: 6m 8s
# 4:	learn: 0.0687887	total: 2.68s	remaining: 6m 6s
# 5:	learn: 0.0687335	total: 3.25s	remaining: 6m 10s
# 6:	learn: 0.0686937	total: 3.69s	remaining: 5m 59s
# 7:	learn: 0.0686615	total: 4.32s	remaining: 6m 8s
# 8:	learn: 0.0686262	total: 4.95s	remaining: 6m 14s
# 9:	learn: 0.0685969	total: 5.67s	remaining: 6m 25s
# 10:	learn: 0.0685699	total: 6.21s	remaining: 6m 23s
# 11:	learn: 0.0685479	total: 6.96s	remaining: 6m 33s
# 12:	learn: 0.0685209	total: 7.82s	remaining: 6m 47s
# 13:	learn: 0.0685034	total: 8.38s	remaining: 6m 44s
# 14:	learn: 0.0684822	total: 8.98s	remaining: 6m 44s
# 15:	learn: 0.0684666	total: 9.6s	remaining: 6m 44s
# 16:	learn: 0.0684525	total: 10.2s	remaining: 6m 42s
# 17:	learn: 0.0684339	total: 11.7s	remaining: 7m 15s
# 18:	learn: 0.0684207	total: 12.2s	remaining: 7m 10s
# 19:	learn: 0.0684067	total: 12.7s	remaining: 7m 4s
# 20:	learn: 0.0683882	total: 13.2s	remaining: 7m
# 21:	learn: 0.0683794	total: 13.7s	remaining: 6m 55s
# 22:	learn: 0.0683673	total: 14.1s	remaining: 6m 48s
# 23:	learn: 0.0683534	total: 14.5s	remaining: 6m 43s
# 24:	learn: 0.0683407	total: 14.9s	remaining: 6m 37s
# 25:	learn: 0.0683301	total: 15.5s	remaining: 6m 36s
# 26:	learn: 0.0683234	total: 16.1s	remaining: 6m 35s
# 27:	learn: 0.0683165	total: 17s	remaining: 6m 41s
# 28:	learn: 0.0683061	total: 17.7s	remaining: 6m 44s
# 29:	learn: 0.0682980	total: 18.3s	remaining: 6m 43s
# 30:	learn: 0.0682900	total: 19.6s	remaining: 6m 56s
# 31:	learn: 0.0682844	total: 20.1s	remaining: 6m 54s
# 32:	learn: 0.0682767	total: 20.7s	remaining: 6m 51s
# 432:	learn: 0.0674152	total: 5m 2s	remaining: 2m 59s
# 433:	learn: 0.0674129	total: 5m 4s	remaining: 2m 59s
# 434:	learn: 0.0674126	total: 5m 5s	remaining: 2m 59s
# 435:	learn: 0.0674113	total: 5m 6s	remaining: 2m 58s
# 436:	learn: 0.0674104	total: 5m 6s	remaining: 2m 57s
# 437:	learn: 0.0674084	total: 5m 7s	remaining: 2m 57s
# 438:	learn: 0.0674051	total: 5m 8s	remaining: 2m 56s
# 439:	learn: 0.0674038	total: 5m 9s	remaining: 2m 55s
# 440:	learn: 0.0674028	total: 5m 10s	remaining: 2m 55s
# 441:	learn: 0.0674003	total: 5m 10s	remaining: 2m 54s
# 442:	learn: 0.0673999	total: 5m 11s	remaining: 2m 53s
# 443:	learn: 0.0673990	total: 5m 12s	remaining: 2m 53s
# 444:	learn: 0.0673983	total: 5m 13s	remaining: 2m 52s
# 445:	learn: 0.0673970	total: 5m 15s	remaining: 2m 52s
# 446:	learn: 0.0673966	total: 5m 15s	remaining: 2m 51s
# 447:	learn: 0.0673948	total: 5m 16s	remaining: 2m 51s
# 448:	learn: 0.0673939	total: 5m 17s	remaining: 2m 50s
# 449:	learn: 0.0673933	total: 5m 17s	remaining: 2m 49s
# 450:	learn: 0.0673921	total: 5m 18s	remaining: 2m 48s
# 451:	learn: 0.0673915	total: 5m 19s	remaining: 2m 48s
# 452:	learn: 0.0673875	total: 5m 19s	remaining: 2m 47s
# 453:	learn: 0.0673868	total: 5m 20s	remaining: 2m 46s
# 454:	learn: 0.0673868	total: 5m 21s	remaining: 2m 45s
# 455:	learn: 0.0673851	total: 5m 21s	remaining: 2m 45s
# 456:	learn: 0.0673841	total: 5m 22s	remaining: 2m 44s
# 457:	learn: 0.0673836	total: 5m 24s	remaining: 2m 44s
# 458:	learn: 0.0673832	total: 5m 25s	remaining: 2m 43s
# 459:	learn: 0.0673814	total: 5m 26s	remaining: 2m 43s
# 460:	learn: 0.0673810	total: 5m 27s	remaining: 2m 42s
# 461:	learn: 0.0673800	total: 5m 28s	remaining: 2m 42s
# 462:	learn: 0.0673796	total: 5m 28s	remaining: 2m 41s
# 463:	learn: 0.0673793	total: 5m 29s	remaining: 2m 40s
# 464:	learn: 0.0673787	total: 5m 30s	remaining: 2m 40s
# 465:	learn: 0.0673782	total: 5m 32s	remaining: 2m 39s
# 466:	learn: 0.0673768	total: 5m 33s	remaining: 2m 39s
# 467:	learn: 0.0673766	total: 5m 34s	remaining: 2m 38s
# 468:	learn: 0.0673761	total: 5m 37s	remaining: 2m 39s
# 469:	learn: 0.0673751	total: 5m 39s	remaining: 2m 38s
# 470:	learn: 0.0673734	total: 5m 40s	remaining: 2m 38s
# 471:	learn: 0.0673730	total: 5m 41s	remaining: 2m 37s
# 472:	learn: 0.0673719	total: 5m 41s	remaining: 2m 36s
# 473:	learn: 0.0673709	total: 5m 42s	remaining: 2m 36s
# 474:	learn: 0.0673705	total: 5m 43s	remaining: 2m 35s
# 475:	learn: 0.0673698	total: 5m 44s	remaining: 2m 34s
# 476:	learn: 0.0673698	total: 5m 44s	remaining: 2m 33s
# 477:	learn: 0.0673692	total: 5m 45s	remaining: 2m 33s
# 478:	learn: 0.0673682	total: 5m 46s	remaining: 2m 32s
# 479:	learn: 0.0673678	total: 5m 47s	remaining: 2m 32s
# 480:	learn: 0.0673673	total: 5m 48s	remaining: 2m 31s
# 481:	learn: 0.0673666	total: 5m 49s	remaining: 2m 30s
# 482:	learn: 0.0673654	total: 5m 49s	remaining: 2m 29s
# 483:	learn: 0.0673651	total: 5m 50s	remaining: 2m 29s
# 484:	learn: 0.0673632	total: 5m 51s	remaining: 2m 28s
# 485:	learn: 0.0673626	total: 5m 51s	remaining: 2m 27s
# 486:	learn: 0.0673614	total: 5m 52s	remaining: 2m 26s
# 487:	learn: 0.0673605	total: 5m 53s	remaining: 2m 26s
# 488:	learn: 0.0673605	total: 5m 53s	remaining: 2m 25s
# 489:	learn: 0.0673593	total: 5m 53s	remaining: 2m 24s
# 490:	learn: 0.0673583	total: 5m 54s	remaining: 2m 23s
# 491:	learn: 0.0673574	total: 5m 55s	remaining: 2m 22s
# 492:	learn: 0.0673565	total: 5m 55s	remaining: 2m 22s
# 493:	learn: 0.0673561	total: 5m 56s	remaining: 2m 21s
# 494:	learn: 0.0673545	total: 5m 57s	remaining: 2m 20s
# 495:	learn: 0.0673527	total: 5m 58s	remaining: 2m 20s
# 496:	learn: 0.0673509	total: 5m 59s	remaining: 2m 19s
# 497:	learn: 0.0673498	total: 5m 59s	remaining: 2m 18s
# 498:	learn: 0.0673494	total: 6m	remaining: 2m 18s
# 499:	learn: 0.0673488	total: 6m 1s	remaining: 2m 17s
# 500:	learn: 0.0673481	total: 6m 1s	remaining: 2m 16s
# 501:	learn: 0.0673476	total: 6m 2s	remaining: 2m 15s
# 502:	learn: 0.0673459	total: 6m 2s	remaining: 2m 14s
# 503:	learn: 0.0673441	total: 6m 3s	remaining: 2m 14s
# 504:	learn: 0.0673435	total: 6m 4s	remaining: 2m 13s
# 505:	learn: 0.0673426	total: 6m 4s	remaining: 2m 12s
# 506:	learn: 0.0673409	total: 6m 5s	remaining: 2m 11s
# 507:	learn: 0.0673393	total: 6m 6s	remaining: 2m 11s
# 508:	learn: 0.0673382	total: 6m 6s	remaining: 2m 10s
# 509:	learn: 0.0673354	total: 6m 7s	remaining: 2m 9s
# 510:	learn: 0.0673336	total: 6m 8s	remaining: 2m 9s
# 511:	learn: 0.0673330	total: 6m 9s	remaining: 2m 8s
# 512:	learn: 0.0673301	total: 6m 10s	remaining: 2m 7s
# 513:	learn: 0.0673296	total: 6m 10s	remaining: 2m 6s
# 514:	learn: 0.0673277	total: 6m 11s	remaining: 2m 6s
# 515:	learn: 0.0673269	total: 6m 12s	remaining: 2m 5s
# 516:	learn: 0.0673251	total: 6m 13s	remaining: 2m 4s
# 517:	learn: 0.0673239	total: 6m 13s	remaining: 2m 4s
# 518:	learn: 0.0673233	total: 6m 14s	remaining: 2m 3s
# 519:	learn: 0.0673223	total: 6m 15s	remaining: 2m 2s
# 654:	learn: 0.0671756	total: 8m 2s	remaining: 25.8s
# 655:	learn: 0.0671751	total: 8m 3s	remaining: 25.1s
# 656:	learn: 0.0671742	total: 8m 4s	remaining: 24.3s
# 657:	learn: 0.0671730	total: 8m 4s	remaining: 23.6s
# 658:	learn: 0.0671725	total: 8m 5s	remaining: 22.8s
# 659:	learn: 0.0671723	total: 8m 7s	remaining: 22.1s
# 660:	learn: 0.0671709	total: 8m 7s	remaining: 21.4s
# 661:	learn: 0.0671687	total: 8m 8s	remaining: 20.7s
# 662:	learn: 0.0671680	total: 8m 9s	remaining: 19.9s
# 663:	learn: 0.0671669	total: 8m 10s	remaining: 19.2s
# 664:	learn: 0.0671627	total: 8m 10s	remaining: 18.5s
# 665:	learn: 0.0671628	total: 8m 11s	remaining: 17.7s
# 666:	learn: 0.0671619	total: 8m 11s	remaining: 17s
# 667:	learn: 0.0671607	total: 8m 12s	remaining: 16.2s
# 668:	learn: 0.0671591	total: 8m 12s	remaining: 15.5s
# 669:	learn: 0.0671583	total: 8m 13s	remaining: 14.7s
# 670:	learn: 0.0671560	total: 8m 14s	remaining: 14s
# 671:	learn: 0.0671554	total: 8m 15s	remaining: 13.3s
# 672:	learn: 0.0671553	total: 8m 16s	remaining: 12.5s
# 673:	learn: 0.0671549	total: 8m 17s	remaining: 11.8s
# 674:	learn: 0.0671535	total: 8m 18s	remaining: 11.1s
# 675:	learn: 0.0671530	total: 8m 18s	remaining: 10.3s
# 676:	learn: 0.0671526	total: 8m 19s	remaining: 9.59s
# 677:	learn: 0.0671515	total: 8m 20s	remaining: 8.85s
# 678:	learn: 0.0671513	total: 8m 20s	remaining: 8.11s
# 679:	learn: 0.0671484	total: 8m 21s	remaining: 7.37s
# 680:	learn: 0.0671474	total: 8m 21s	remaining: 6.63s
# 681:	learn: 0.0671452	total: 8m 22s	remaining: 5.9s
# 682:	learn: 0.0671452	total: 8m 22s	remaining: 5.15s
# 683:	learn: 0.0671445	total: 8m 23s	remaining: 4.42s
# 684:	learn: 0.0671440	total: 8m 24s	remaining: 3.68s
# 685:	learn: 0.0671428	total: 8m 24s	remaining: 2.94s
# 686:	learn: 0.0671425	total: 8m 25s	remaining: 2.21s
# 687:	learn: 0.0671400	total: 8m 26s	remaining: 1.47s
# 688:	learn: 0.0671397	total: 8m 26s	remaining: 735ms
# 689:	learn: 0.0671392	total: 8m 27s	remaining: 0us

# %%
submission = pd.DataFrame({
    'ParcelId': test_df['ParcelId'],
})
test_dates = {
    '201612': pd.Timestamp('2016-11-30')
}
for label, test_date in test_dates.items():
    print("Predicting for: %s ... " % (label))
    submission[label] = y_pred
    
submission.to_csv(data_path + 'Model_5_CatBoost.csv', float_format='%.6f',index=False)
# Out:
# Predicting for: 201612 ...

# %%
predictions_model_5 = pd.read_csv(data_path + 'Model_5_CatBoost.csv')
predictions_model_5.head()
# Out:
#    ParcelId    201612
# 0  10754147  0.017949
# 1  10759547  0.012833
# 2  10843547  0.034269
# 3  10859147  0.032328
# 4  10879947  0.015110
